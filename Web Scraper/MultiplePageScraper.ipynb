# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse
import xlwt

# %% [markdown]
# ### HTTP Requests

# %% [markdown]
# #### Store website inside variable

# %%
website = 'https://www.gumtree.com/cars/london'

# %% [markdown]
# #### Get request

# %%
response = requests.get(website)

# %% [markdown]
# #### Status Code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# #### Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 8]>
# <html class="no-js ie8 device-desktop" lang="en-GB">
# <![endif]-->
# <!--[if IE 9]>
# <html class="no-js ie9 device-desktop" lang="en-GB">
# <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="device-desktop no-js" lang="en-GB">
# <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="#0D475C" name="theme-color"/>
# <meta content="no" name="msapplication-tap-highlight">
# <meta content="Find amazing local prices on used cars for sale in London ✅ Shop hassle-free with Gumtree, your local buying &amp; selling community." name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.gumtree.com/cars/london" property="og:url"/>
# <meta content="712402357, 754015025, 61305173" property="fb:admins"/>
# <meta content="14169285463" property="fb:page_id"/>
# <meta content="14169285463" property="fb:app_id"/>
# <meta content="Gumtree.com" property="og:site_name"/>
# <meta content="Used Cars for Sale in London | Great Local Deals | Gumtree" property="og:title"/>
# <meta content="United Kingdom" property="og:country-name"/>
# <meta content="Find amazing local prices on used cars for sale in London ✅ Shop hassle-free with Gumtree, your local buying &amp; selling community." property="og:description"/>
# <meta content="London" property="og:region"/>
# <meta content="London" property="og:locality"/>
# <meta content="" property="og:postal-code"/>
# <meta content="https://www.gumtree.com/static/1/resources/assets/rwd/images/app-icons/3b7c65099ebe8bd2f3e37069.gumtreefacebook-icon-600x600.jpg" property="og:image"/>
# <meta content="600" property="og:image:width"/>
# <meta content="600" property="og:image:height"/>
# <meta content="image/jpeg" property="og:image:type"/>
# <meta content="@Gumtree" name="twitter:site"/>
# <meta content="Used Cars for Sale in London | Great Local Deals | Gumtree" name="twitter:title"/>
# <meta content="https://www.gumtree.com/cars/london" name="twitter:url"/>
# <meta content="Find amazing local prices on used cars for sale in London ✅ Shop hassle-free with Gumtree, your local buying &amp; selling community." name="twitter:description"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <link href="/cars/london/page2" rel="next"/>
# <link href="https://www.gumtree.com/cars/london" rel="canonical"/>
# <link href="https://www.gumtree.com/static/1/resources/assets/rwd/images/app-icons/7ff3daeaff3f7cefe5f70865.favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="https://www.gumtree.com/static/1/resources/assets/rwd/images/app-icons/b7f6c9b5d9c9178a12bbe37e.apple-touch-icon-57x57.png" rel="apple-touch-icon"/>
# <link href="https://www.gumtree.com/static/1/resources/assets/rwd/images/app-icons/b7f6c9b5d9c9178a12bbe37e.apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://www.gumtree.com/static/1/resources/assets/rwd/images/app-icons/54f125680d5e5df336f02a8f.apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://www.gumtree.com/static/1/resources/assets/rwd/images/app-icons/c8e307fa95e0b7bca298663c.apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://www.gumtree.com/static/1/resources/assets/rwd/images/app-icons/d34596d747a82e90c645335d.apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://www.gumtree.com/static/1/resources/assets/rwd/images/app-icons/2e232c2eb6cc890396e6ad9d.apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://www.gumtree.com/static/1/resources/assets/rwd/images/app-icons/df45b92e61225ba3ddbe7a09.apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://www.gumtree.com/static/1/resources/assets/rwd/images/app-icons/8f90429d16b8cebd29655967.apple-touch-icon-167x167.png" rel="apple-touch-icon" sizes="167x167"/>
# <link href="https://www.gumtree.com/static/1/resources/assets/rwd/images/app-icons/7ec446eb998ece80ea734745.apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link as="font" crossorigin="anonymous" href="https://www.gumtree.com/static/1/resources/assets/rwd/font/gumtree/65a0c09632c710a438830a3a.gumtree.woff2" rel="preload" type="font/woff2"/>
# <link crossorigin="anonymous" href="https://fonts.gstatic.com" rel="preconnect"/>
# <style type="text/css">
# .listing-maxi .listing-content,.media>.media-body-overflow{overflow:hidden}.media>.media-body{display:table-cell;vertical-align:top;width:10000px!important}.box-article:after,.box-article:before,.box-info:after,.box-info:before,.box-pullout:after,.box-pullout:before,.box:after,.box:before,.btn-group:after,.btn-group:before,.clearfix:after,.clearfix:before,.dl-attribute-list dd:after,.dl-attribute-list dd:before,.dl-table:after,.dl-table:before,.filmstrip-header:after,.filmstrip-header:before,.footer-primary-links:after,.footer-primary-links:before,.footer-social-buttons:after,.footer-social-buttons:before,.form-row-inline:after,.form-row-inline:before,.form-row:after,.form-row:before,.header-popular-searches ul:after,.header-popular-searches ul:before,.header-search-inputs:after,.header-search-inputs:before,.listing-maxi .listing-link:after,.listing-maxi .listing-link:before,.listing-maxi:after,.listing-maxi:before,.media:after,.media:before,.nav-categories:after,.nav-categories:before,.notification-box:after,.notification-box:before,.panel-content:after,.panel-content:before,.panel-dark:after,.panel-dark:before,.panel:after,.panel:before,.striped-list-even>li:after,.striped-list-even>li:before,.striped-list>li:after,.striped-list>li:before,.tabs-triggers:after,.tabs-triggers:before{content:" ";display:table}.box-article:after,.box-info:after,.box-pullout:after,.box:after,.btn-group:after,.clearfix:after,.dl-attribute-list dd:after,.dl-table:after,.filmstrip-header:after,.footer-primary-links:after,.footer-social-buttons:after,.form-row-inline:after,.form-row:after,.header-popular-searches ul:after,.header-search-inputs:after,.listing-maxi .listing-link:after,.listing-maxi:after,.media:after,.nav-categories:after,.notification-box:after,.panel-content:after,.panel-dark:after,.panel:after,.striped-list-even>li:after,.striped-list>li:after,.tabs-triggers:after{clear:both}.btn-indent,.panel-content,.panel-title{padding:9.6px 8px}
# /*! normalize.css 2012-03-11T12:53 UTC - http://github.com/necolas/normalize.css */article,aside,details,figcaption,figure,footer,header,hgroup,main,nav,section,summary{display:block}audio,canvas,video{display:inline-block}audio:not([controls]){display:none;height:0}body{margin:0}abbr[title]{border-bottom:1px dotted}b,strong{font-weight:700}blockquote{margin:16px 40px}dfn{font-style:italic}mark{background:#ff0;color:#000}p,pre{margin:0}code,kbd,pre,samp{font-size:16px}pre{white-space:pre;white-space:pre-wrap;word-wrap:break-word}q{quotes:none}small,sub,sup{font-size:75%}sub,sup{line-height:0;position:relative;vertical-align:baseline}sup{top:-3px}sub{bottom:4px}dd,dl,dt,menu,ol,ul{margin:0;padding:0}dd,dl,dt,ol,ul{list-style:none;list-style-image:none}img{border:0;-ms-interpolation-mode:bicubic}svg:not(:root){overflow:hidden}figure,form{margin:0}fieldset{margin:0}fieldset,legend{padding:0;border:0}button,input,select,textarea{font-size:100%;margin:0;vertical-align:baseline}button,input{line-height:normal}.button,button,input[type=button],input[type=reset],input[type=submit]{cursor:pointer;-webkit-appearance:button}button[disabled],input[disabled]{cursor:default}input[type=checkbox],input[type=radio]{box-sizing:border-box;padding:0}input[type=search]{-webkit-appearance:textfield;box-sizing:content-box}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0}textarea{overflow:auto;vertical-align:top}table{border-collapse:collapse;border-spacing:0}*,:after,:before{box-sizing:border-box}body{margin:0 auto;width:100%;background-color:#fff}html{-webkit-text-size-adjust:none}.grid-container{display:block;margin-right:auto;margin-left:auto;padding-left:8px;padding-right:8px}.grid-container:after,.grid-container:before{content:" ";display:table}.grid-container:after{clear:both}.grid-row,[class*=" grid-tiles"],[class^=grid-tiles]{margin-left:-8px;margin-right:-8px}.grid-row:after,.grid-row:before,[class*=" grid-tiles"]:after,[class*=" grid-tiles"]:before,[class^=grid-tiles]:after,[class^=grid-tiles]:before{content:" ";display:table}.grid-row:after,[class*=" grid-tiles"]:after,[class^=grid-tiles]:after{clear:both}.grid-row.align-height,[class*=" grid-tiles"].align-height,[class^=grid-tiles].align-height{display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap}[class*=" grid-col"],[class*=" grid-tiles"]>li,[class^=grid-col],[class^=grid-tiles]>li{float:left;min-height:1px;padding-left:8px;padding-right:8px;width:100%;margin-left:0}.grid-col-1,.grid-col-2,.grid-col-3,.grid-col-4,.grid-col-5,.grid-col-6,.grid-col-7,.grid-col-8,.grid-col-9,.grid-col-10,.grid-col-11,.grid-col-12{right:auto;left:auto}.grid-col-right{float:right}.grid-col-left{float:left}.grid-col-1,.grid-tiles-1>li,.grid-tiles-first-1>li:first-of-type{width:8.33333%}.grid-col-offset-1{margin-left:8.33333%}.grid-col-push-1{position:relative;left:8.33333%}.grid-col-pull-1{position:relative;right:8.33333%}.grid-col-2,.grid-tiles-2>li,.grid-tiles-first-2>li:first-of-type{width:16.66667%}.grid-col-offset-2{margin-left:16.66667%}.grid-col-push-2{position:relative;left:16.66667%}.grid-col-pull-2{position:relative;right:16.66667%}.grid-col-3,.grid-tiles-3>li,.grid-tiles-first-3>li:first-of-type{width:25%}.grid-col-offset-3{margin-left:25%}.grid-col-push-3{position:relative;left:25%}.grid-col-pull-3{position:relative;right:25%}.grid-col-4,.grid-tiles-4>li,.grid-tiles-first-4>li:first-of-type{width:33.33333%}.grid-col-offset-4{margin-left:33.33333%}.grid-col-push-4{position:relative;left:33.33333%}.grid-col-pull-4{position:relative;right:33.33333%}.grid-col-5,.grid-tiles-5>li,.grid-tiles-first-5>li:first-of-type{width:41.66667%}.grid-col-offset-5{margin-left:41.66667%}.grid-col-push-5{position:relative;left:41.66667%}.grid-col-pull-5{position:relative;right:41.66667%}.grid-col-6,.grid-tiles-6>li,.grid-tiles ...
# /*!
# * animate.css -http://daneden.me/animate
# * Version - 3.5.1
# * Licensed under the MIT license - http://opensource.org/licenses/MIT
# *
# * Copyright (c) 2016 Daniel Eden
# */@-webkit-keyframes c{0%{-webkit-transform:translate3d(0,-10%,0);transform:translate3d(0,-10%,0);visibility:visible}to{-webkit-transform:translateZ(0);transform:translateZ(0)}}@keyframes c{0%{-webkit-transform:translate3d(0,-10%,0);transform:translate3d(0,-10%,0);visibility:visible}to{-webkit-transform:translateZ(0);transform:translateZ(0)}}@-webkit-keyframes d{0%{-webkit-transform:translate3d(10%,0,0);transform:translate3d(10%,0,0);visibility:visible}to{-webkit-transform:translateZ(0);transform:translateZ(0)}}@keyframes d{0%{-webkit-transform:translate3d(10%,0,0);transform:translate3d(10%,0,0);visibility:visible}to{-webkit-transform:translateZ(0);transform:translateZ(0)}}@-webkit-keyframes e{0%{-webkit-transform:scaleX(1);transform:scaleX(1)}50%{-webkit-transform:scale3d(1.05,1.05,1.05);transform:scale3d(1.05,1.05,1.05)}to{-webkit-transform:scaleX(1);transform:scaleX(1)}}@-webkit-keyframes f{0%{-webkit-transform:translateZ(0);transform:translateZ(0);opacity:0}to{opacity:1}}@keyframes f{0%{-webkit-transform:translateZ(0);transform:translateZ(0);opacity:0}to{opacity:1}}@-webkit-keyframes g{0%{opacity:0;-webkit-transform:translate3d(0,3%,0);transform:translate3d(0,3%,0)}to{opacity:1;-webkit-transform:none;transform:none}}@keyframes g{0%{opacity:0;-webkit-transform:translate3d(0,3%,0);transform:translate3d(0,3%,0)}to{opacity:1;-webkit-transform:none;transform:none}}@-webkit-keyframes h{0%{opacity:0;-webkit-transform:translate3d(0,-10%,0);transform:translate3d(0,-10%,0)}to{opacity:1;-webkit-transform:none;transform:none}}@keyframes h{0%{opacity:0;-webkit-transform:translate3d(0,-10%,0);transform:translate3d(0,-10%,0)}to{opacity:1;-webkit-transform:none;transform:none}}.slideInRight{-webkit-animation:d .2s linear 1;animation:d .2s linear 1}.slideInDown{-webkit-animation:c .2s linear 1;animation:c .2s linear 1}.pulse{-webkit-animation:e 1s linear infinite;animation:e 1s linear infinite}.fadeInUp{-webkit-animation:g .5s linear;animation:g .5s linear}.will-change{will-change:auto}.hero-msg{padding:0 18px}.hero-msg .hero-img{max-height:100%;max-width:100%;vertical-align:bottom;padding-top:1px}.hero-msg .hero-title{font-size:24px;margin:24px 0}.hero-msg .hero-content{padding:18px}.hero-msg .hero-img{padding:1px 0 0}.panel{background:#fff}.panel-title{margin-bottom:0;border-bottom:1px solid #d8d6d9;background-color:#fafafa;border-radius:5px 5px 0 0}.panel-summary-basic{position:absolute;right:16px;top:8px}.panel-summary{position:absolute;right:13px;top:14px;color:#635b67;font-size:14px;font-weight:400;text-align:right;width:130px}.panel-validation{line-height:.5;display:none}.panel-validation:before{padding-right:4px}.is-valid .panel-validation{color:#52a744;display:inline-block}.is-invalid .panel-validation{color:#e52815;display:inline-block}.is-beingedited .panel-validation{color:#d8d6d9;display:inline-block}.syi-info-box{background:#e6ecee;border:none;display:-webkit-flex;display:-ms-flexbox;display:flex}.syi-info-box-teaser{color:#0d475c;margin-bottom:6px}.syi-info-box.phishing-info{display:-webkit-flex;display:-ms-flexbox;display:flex;float:left;clear:both;margin:18px 8px -12px;padding:16px}.syi-info-box.phishing-info p{color:#0d475c;margin:0}.syi-info-box.phishing-info .icn-bell{color:#0d475c;padding-top:4px}.syi-info-box .icn-paw{font-size:25px}.syi-info-box-content-toggler.override-gumtree-ui-library.toggler{position:absolute;bottom:0;right:12px;color:#007fb0}.syi-info-box .toggle{display:inline}.syi-info-box .toggle.open .show-more{display:none}.syi-info-box .toggle.open .show-less{display:block}.syi-info-box .toggle .show-less{display:none}.category-change-radio{margin-right:24px}.category-change-panel{background:#eef8ed;color:#52a744;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-ms-flex-align:center;align-items:center}.category-change-panel .panel-validation:before{font-size:26px}.category-change-panel-text-content,.category-change-panel-text-title{margin:0}.panel-dark{background:#3c3241;co ...
# /*# sourceMappingURL=critical.css.map */</style>
# <!--[if gt IE 9]><!-->
# <link as="style" href="https://www.gumtree.com/static/1/resources/assets/rwd/style/framework/css/541274ae705ac51d20debc60.buyer.css" onload="this.rel='stylesheet'" rel="preload"/>
# <!--<![endif]-->
# <noscript>
# <link href="https://www.gumtree.com/static/1/resources/assets/rwd/style/framework/css/541274ae705ac51d20debc60.buyer.css" rel="stylesheet"/>
# </noscript>
# <!--[if lte IE 9]>
# <link rel="stylesheet" href="https://www.gumtree.com/static/1/resources/assets/rwd/style/framework/css/541274ae705ac51d20debc60.buyer.css">
# <link rel="stylesheet" href="https://www.gumtree.com/static/1/resources/assets/rwd/style/framework/css/3e26c5121130e1598d3d645e.ie.css">
# <![endif]--><link href="android-app://com.gumtree.android/gumtree/link?nav=search&amp;url=https%3A%2F%2Fmy.gumtree.com%3Fsearch_category%3Dcars%26search_location%3Dlondon" rel="alternate"><script>
# !function(e,o,n,i){if(!e){e=e||{},window.permutive=e,e.q=[];var t=function(){return([1e7]+-1e3+-4e3+-8e3+-1e11).replace(/[018]/g,function(e){return(e^(window.crypto||window.msCrypto).getRandomValues(new Uint8Array(1))[0]&15>>e/4).toString(16)})};e.config=i||{},e.config.apiKey=o,e.config.workspaceId=n,e.config.environment=e.config.environment||"production",(window.crypto||window.msCrypto)&&(e.config.viewId=t());for(var g=["addon","identify","track","trigger","query","segment","segments","ready","on","once","user","consent"],r=0;r<g.length;r++){var w=g[r];e[w]=function(o){return function(){var n=Array.prototype.slice.call(arguments,0);e.q.push({functionName:o,arguments:n})}}(w)}}}(window.permutive,"ec6008f1-a097-4bc6-bd7e-876e6e2c3013","83ec9453-32cb-4eb3-88f7-2259d89a79b9",{"consentRequired": true});
# window.googletag=window.googletag||{},window.googletag.cmd=window.googletag.cmd||[],window.googletag.cmd.push(function(){if(0===window.googletag.pubads().getTargeting("permutive").length){var e=window.localStorage.getItem("_pdfps");window.googletag.pubads().setTargeting("permutive",e?JSON.parse(e):[]);var o=window.localStorage.getItem("permutive-id");o&&(window.googletag.pubads().setTargeting("puid",o),window.googletag.pubads().setTargeting("ptime",Date.now().toString())),window.permutive.config.viewId&&window.googletag.pubads().setTargeting("prmtvvid",window.permutive.config.viewId),window.permutive.config.workspaceId&&window.googletag.pubads().setTargeting("prmtvwid",window.permutive.config.workspaceId)}});
# (function initialisePermutive(window) {
# try {
# const dataLayer = {"time":1651156080466,"s":{"sr_oa":[{"id":1431288397},{"id":1431288213},{"id":1426180182},{"id":1430907948},{"id":1431063037},{"id":1430145739},{"id":1428339202},{"id":1425755514},{"id":1427677057},{"id":1427677295},{"id":1426259638},{"id":1426180324},{"id":1424655904},{"id":1428569048},{"id":1425745160},{"id":1425020989},{"id":1426398750},{"id":1426180262},{"id":1425744889},{"id":1426617023},{"id":1426621280},{"id":1430907038},{"id":1426823656},{"id":1430147901},{"id":1428999518}],"kw":"","pn":1,"tr":17045,"sr_ta":[{"id":1430580715,"ftr":["FEATURED"]},{"id":1426953836,"ftr":["FEATURED"]},{"id":1430993902,"ftr":["FEATURED"]},{"id":1430953463,"ftr":["FEATURED"]},{"id":1431236237,"ftr":["FEATURED"]}],"sr_na":[],"tp":50,"attr":{},"rs":[],"t":"Browse"},"c":{"c":{"id":9311},"l0":{"id":1},"l1":{"id":2551},"l2":{"id":9311}},"l":{"c":{"id":10000344},"l0":{"id":10000392},"l1":{"id":10000393},"l2":{"id":10000344}},"p":{"pl":"responsive","t":"ResultsBrowse"},"d":{"ck":"c482f98f7599247794cb0401cdf899c70a95042d77cd346eb95e15029ddff12d","s_ck":"node01lrhcpkg6u6kw1bte114oconph825692","t":"d"},"u":{"li":false,"tg":{"stg":"","ptg":"GTALL-24856-D;GTALL-19721-A;GTALL-25488-B;GTALL-24237-B;GTALL-17502-B;GTALL-17844-B;GTALL-18911-A;GTALL-26059-B;GTALL-26257-A;GTALL-25740-B;GTALL-23001-A;GTALL-26399-C;GTALL-21241-B;GTALL-26394-B;GTALL-25681-A;GTALL-24052-B;GTALL-26051-A;GTALL-16230-A;GTALL-17010-B;GTALL-24788-C;GTALL-22323-B;GTALL-24568-B;GTALL-23339-B;GTALL-25159-B;GTALL-20842-B;GTALL-19434-B;GTALL-25238-B;GTALL-25975-B;GTALL-19559-A;GTALL-25498-B;GTALL-24761-B;GTALL-23034-B;GTALL-21395-B;GTALL-25493-A;GTALL-16805-B;GTALL-24180-B;GTALL-15996-A;GTALL-16886-B;GTALL-19291-B;GTALL-20779-A;GTALL-25508-B"}},"name":"SrpViewEvent"};
# const convertDateToISOFormat = (timestamp) => {
# const date = new Date(timestamp);
# return date.toISOString();
# };
# permutive.addon('web', {
# page: {
# pageType: dataLayer.p.t,
# platform: dataLayer.p.pl,
# deviceSize: "desktop",
# ...(dataLayer.a && dataLayer.a.attr && dataLayer.a.attr.vehicle_fuel_type && {
# vehicle: {
# make: dataLayer.a.attr.vehicle_make,
# model: dataLayer.a.attr.vehicle_model,
# transmission: dataLayer.a.attr.vehicle_transmission,
# fuelType: dataLayer.a.attr.vehicle_fuel_type,
# },
# }),
# ...(dataLayer.s && {
# search: {
# type: dataLayer.s.t,
# ...(dataLayer.s.kw && { keyword: dataLayer.s.kw }),
# ...(dataLayer.s.pn && { pageNumber: dataLayer.s.pn }),
# ...(dataLayer.s.tr && { totalResults: dataLayer.s.tr }),
# },
# }),
# ...(dataLayer.c && {
# category: {
# ...(dataLayer.c.l0 && {
# l0: {
# id: dataLayer.c.l0.id.toString(),
# },
# }),
# ...(dataLayer.c.l1 && {
# l1: {
# id: dataLayer.c.l1.id.toString(),
# },
# }),
# ...(dataLayer.c.l2 && {
# l2: {
# id: dataLayer.c.l2.id.toString(),
# },
# }),
# ...(dataLayer.c.l3 && {
# l3: {
# id: dataLayer.c.l3.id.toString(),
# },
# }),
# ...(dataLayer.c.l4 && {
# l4: {
# id: dataLayer.c.l4.id.toString(),
# },
# }),
# }
# }),
# ...(dataLayer.l && {
# location: {
# ...(dataLayer.l.l0 && {
# l0: {
# id: dataLayer.l.l0.id.toString(),
# },
# }),
# ...(dataLayer.l.l1 && {
# l1: {
# id: dataLayer.l.l1.id.toString(),
# },
# }),
# ...(dataLayer.l.l2 && {
# l2: {
# id: dataLayer.l.l2.id.toString(),
# },
# }),
# ...(dataLayer.l.l3 && {
# l3: {
# id: dataLayer.l.l3.id.toString(),
# },
# }),
# ...(dataLayer.l.l4 && {
# l4: {
# id: dataLayer.l.l4.id.toString(),
# },
# }),
# }
# }),
# user: {
# loggedIn: false,
# },
# ...(dataLayer.a && dataLayer.a.id && {
# ad: {
# id: dataLayer.a.id.toString(),
# user: {
# type: dataLayer.a.u.at,
# },
# ...(dataLayer.a.attr && dataLayer.a.attr.seller_type && { sellerType: dataLayer.a.attr.seller_type }),
# ...(dataLayer.a.prc && {
# price: {
# ...(dataLayer.a.prc.amt && { amount: dataLayer.a.prc.amt }),
# ...(dataLayer.a.prc.cur && { currency: dataLayer.a.prc.cur }),
# },
# }),
# descriptionLength: dataLayer.a.dl,
# imageCount: dataLayer.a.ic,
# creationDate: dataLayer.a.cdt && convertDateToISOFormat(dataLayer.a.cdt),
# lastPublishedDate: dataLayer.a.lpdt && convertDateToISOFormat(dataLayer.a.lpdt),
# advertClickSource: dataLayer.a.acs,
# },
# }),
# ...(dataLayer.m && dataLayer.m.t && {
# message: {
# replyType: dataLayer.m.t,
# replyDirection: dataLayer.m.dr,
# medium: dataLayer.m.mdm,
# },
# }),
# ...(dataLayer.o && {
# order: {
# id: dataLayer.o.id.toString(),
# ...(dataLayer.o.oi && {
# item: dataLayer.o.oi.map(item => ({
# productName: item.prd.n,
# netPrice: item.na,
# tax: item.tx,
# })),
# }),
# ...(dataLayer.o.py && {
# payment: {
# method: dataLayer.o.py.pm,
# provider: dataLayer.o.py.pp,
# }
# }),
# }
# }),
# }
# });
# } catch(ex) {
# document.addEventListener('DOMContentLoaded', () => {
# window.dataLayer.push({
# event: 'JavaScriptClientSideError',
# eventAction: 'JavaScriptClientSideError',
# eventCategory: 'JavaScriptClientSideError',
# eventLabel: '__permutiveScript.ftl: ' + ex,
# });
# });
# }
# })(window);
# </script>
# <script async="" src="https://83ec9453-32cb-4eb3-88f7-2259d89a79b9.edge.permutive.app/83ec9453-32cb-4eb3-88f7-2259d89a79b9-web.js"></script>
# <!--GumTree Hybrid Integration Generated 07.27.21-->
# <script async="" src="https://confiant-integrations.global.ssl.fastly.net/IsHYOMWVLWBKQkWO76nnaFuQoQI/gpt_and_prebid_v3l/config.js"></script>
# <script type="text/javascript">
# (function(){
# var isChrome = !!window.chrome;
# var isDesktopPlatform = window.navigator.platform === 'MacIntel' ||
# window.navigator.platform === 'CrOS' ||
# window.navigator.platform === 'Win32' ||
# window.navigator.platform === 'Win64' ||
# /Linux/.test(window.navigator.platform);
# var isMobilePlatform = /Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini|Mobile|mobile|CriOS/i.test(window.navigator.userAgent);
# var isLikelyAdBlockerFree = (!isChrome || !isDesktopPlatform || isMobilePlatform);
# if (!isLikelyAdBlockerFree) {
# var js = document.createElement('script');
# js.src = 'https://static.criteo.net/js/ld/publishertag.js';
# document.getElementsByTagName('head')[0].appendChild(js);
# }
# })();
# </script>
# <script>
# LUX=(function(){var a=("undefined"!==typeof(LUX)&&"undefined"!==typeof(LUX.gaMarks)?LUX.gaMarks:[]);var d=("undefined"!==typeof(LUX)&&"undefined"!==typeof(LUX.gaMeasures)?LUX.gaMeasures:[]);var j="LUX_start";var k=window.performance;var l=("undefined"!==typeof(LUX)&&LUX.ns?LUX.ns:(Date.now?Date.now():+(new Date())));if(k&&k.timing&&k.timing.navigationStart){l=k.timing.navigationStart}function f(){if(k&&k.now){return k.now()}var o=Date.now?Date.now():+(new Date());return o-l}function b(n){if(k){if(k.mark){return k.mark(n)}else{if(k.webkitMark){return k.webkitMark(n)}}}a.push({name:n,entryType:"mark",startTime:f(),duration:0});return}function m(p,t,n){if("undefined"===typeof(t)&&h(j)){t=j}if(k){if(k.measure){if(t){if(n){return k.measure(p,t,n)}else{return k.measure(p,t)}}else{return k.measure(p)}}else{if(k.webkitMeasure){return k.webkitMeasure(p,t,n)}}}var r=0,o=f();if(t){var s=h(t);if(s){r=s.startTime}else{if(k&&k.timing&&k.timing[t]){r=k.timing[t]-k.timing.navigationStart}else{return}}}if(n){var q=h(n);if(q){o=q.startTime}else{if(k&&k.timing&&k.timing[n]){o=k.timing[n]-k.timing.navigationStart}else{return}}}d.push({name:p,entryType:"measure",startTime:r,duration:(o-r)});return}function h(n){return c(n,g())}function c(p,o){for(i=o.length-1;i>=0;i--){var n=o[i];if(p===n.name){return n}}return undefined}function g(){if(k){if(k.getEntriesByType){return k.getEntriesByType("mark")}else{if(k.webkitGetEntriesByType){return k.webkitGetEntriesByType("mark")}}}return a}return{mark:b,measure:m,gaMarks:a,gaMeasures:d}})();LUX.ns=(Date.now?Date.now():+(new Date()));LUX.ac=[];LUX.cmd=function(a){LUX.ac.push(a)};LUX.init=function(){LUX.cmd(["init"])};LUX.send=function(){LUX.cmd(["send"])};LUX.addData=function(a,b){LUX.cmd(["addData",a,b])};LUX_ae=[];window.addEventListener("error",function(a){LUX_ae.push(a)});LUX_al=[];if("function"===typeof(PerformanceObserver)&&"function"===typeof(PerformanceLongTaskTiming)){var LongTaskObserver=new PerformanceObserver(function(c){var b=c.getEntries();for(var a=0;a<b.length;a++){var d=b[a];LUX_al.push(d)}});try{LongTaskObserver.observe({type:["longtask"]})}catch(e){}};
# LUX.label='[Gumtree Frontend]ResultsBrowse:cars-vans-motorbikes';
# LUX.addData('GTALL-24856','D');LUX.addData('GTALL-19721','A');LUX.addData('GTALL-25488','B');LUX.addData('GTALL-24237','B');LUX.addData('GTALL-17502','B');LUX.addData('GTALL-17844','B');LUX.addData('GTALL-18911','A');LUX.addData('GTALL-26059','B');LUX.addData('GTALL-26257','A');LUX.addData('GTALL-25740','B');LUX.addData('GTALL-23001','A');LUX.addData('GTALL-26399','C');LUX.addData('GTALL-21241','B');LUX.addData('GTALL-26394','B');LUX.addData('GTALL-25681','A');LUX.addData('GTALL-24052','B');LUX.addData('GTALL-26051','A');LUX.addData('GTALL-16230','A');LUX.addData('GTALL-17010','B');LUX.addData('GTALL-24788','C');LUX.addData('GTALL-22323','B');LUX.addData('GTALL-24568','B');LUX.addData('GTALL-23339','B');LUX.addData('GTALL-25159','B');LUX.addData('GTALL-20842','B');LUX.addData('GTALL-19434','B');LUX.addData('GTALL-25238','B');LUX.addData('GTALL-25975','B');LUX.addData('GTALL-19559','A');LUX.addData('GTALL-25498','B');LUX.addData('GTALL-24761','B');LUX.addData('GTALL-23034','B');LUX.addData('GTALL-21395','B');LUX.addData('GTALL-25493','A');LUX.addData('GTALL-16805','B');LUX.addData('GTALL-24180','B');LUX.addData('GTALL-15996','A');LUX.addData('GTALL-16886','B');LUX.addData('GTALL-19291','B');LUX.addData('GTALL-20779','A');LUX.addData('GTALL-25508','B');
# </script>
# <script async="" crossorigin="anonymous" defer="" src="https://cdn.speedcurve.com/js/lux.js?id=53934380"></script>
# <script>
# // Setup Gum
# window.Gum = window.Gum ? window.Gum : {};
# // Configure dev vars
# Gum.devHost = window.devHost || '';
# // Setup components namespace
# Gum.ComponentManager = {};
# Gum.Components = {};
# Gum.components = {};
# Gum.native = {};
# Gum.domReady = false;
# Gum.images = {};
# Gum.React = {};
# Gum.Templates = {};
# Gum.breakpoints = [
# {
# tshirt: 'xs',
# 'min': 0,
# 'max': 479,
# 'adsense': 'responsive320',
# 'gutter': 15
# },
# {
# 'tshirt': 's',
# 'min': 480,
# 'max': 766,
# 'adsense': 'responsive481',
# 'gutter': 15
# },
# {
# 'tshirt': 'm',
# 'min': 767,
# 'max': 1023,
# 'adsense': 'responsive768',
# 'gutter': 15
# },
# {
# 'tshirt': 'l',
# 'min': 1024,
# 'max': 1279,
# 'adsense': 'responsive1024',
# 'gutter': 15
# },
# {
# 'tshirt': 'xl',
# 'min': 1280,
# 'max': 1348,
# 'adsense': 'responsive1280',
# 'gutter': 15
# },
# {
# 'tshirt': 'xxl',
# 'min': 1349,
# 'max': Infinity,
# 'adsense': 'responsive1349',
# 'gutter': 15
# }
# ];
# Gum.ads = {
# display: {
# base: {},
# slots: {},
# config: {}
# },
# adsense: {
# base: {},
# slots: {},
# config: {}
# },
# bing: {
# base: {},
# slots: {},
# config: {}
# },
# partnership: {
# slots: {}
# }
# };
# Gum.triggeredEvents = [];
# // Create namespace for googletags
# window.googletag = window.googletag || {};
# googletag.cmd = googletag.cmd || [];
# Gum.domain = {
# buyer: "https://www.gumtree.com",
# seller: "https://my.gumtree.com",
# assets: "https://www.gumtree.com/static/1/resources/assets/",
# device: 'desktop',
# deviceOs: 'UNKNOWN',
# features: [
# "SEARCH_ES6",
# ],
# domain: 'gumtree.com',
# ab: {"GTALL-24856" : "D","GTALL-19721" : "A","GTALL-25488" : "B","GTALL-24237" : "B","GTALL-17502" : "B","GTALL-17844" : "B","GTALL-18911" : "A","GTALL-26059" : "B","GTALL-26257" : "A","GTALL-25740" : "B","GTALL-23001" : "A","GTALL-26399" : "C","GTALL-21241" : "B","GTALL-26394" : "B","GTALL-25681" : "A","GTALL-24052" : "B","GTALL-26051" : "A","GTALL-16230" : "A","GTALL-17010" : "B","GTALL-24788" : "C","GTALL-22323" : "B","GTALL-24568" : "B","GTALL-23339" : "B","GTALL-25159" : "B","GTALL-20842" : "B","GTALL-19434" : "B","GTALL-25238" : "B","GTALL-25975" : "B","GTALL-19559" : "A","GTALL-25498" : "B","GTALL-24761" : "B","GTALL-23034" : "B","GTALL-21395" : "B","GTALL-25493" : "A","GTALL-16805" : "B","GTALL-24180" : "B","GTALL-15996" : "A","GTALL-16886" : "B","GTALL-19291" : "B","GTALL-20779" : "A","GTALL-25508" : "B"},
# pageType: "ResultsBrowse",
# l1CategoryName: "cars-vans-motorbikes",
# newUser: true,
# userLoggedIn: false,
# pageData: {
# "formState": {
# "featured_filter" : false
# ,
# "q" : ""
# ,
# "search_location" : "london"
# ,
# "search_category" : "cars"
# ,
# "urgent_filter" : false
# ,
# "sort" : "date"
# ,
# "search_scope" : false
# ,
# "photos_filter" : false
# },
# "searchSaved": false,
# "deviceOS": "UNKNOWN",
# "currentPage": 1,
# "results": {
# "natural": 25,
# "nearby": 0,
# "totalSearchAdsNumFound": 17045,
# "cameFromZeroSrp": false
# },
# sortFilters: [
# {
# value: "date",
# displayValue: "Most recent first",
# },
# {
# value: "price_lowest_first",
# displayValue: "Price: Low to High",
# },
# {
# value: "price_highest_first",
# displayValue: "Price: High to Low",
# },
# {
# value: "distance",
# displayValue: "Nearest first",
# },
# ]
# }
# ,
# env: "PROD",
# pollingFrequency: 7,
# tracking: {
# comScore: {
# data: {
# c1: "2",
# c2: "7849854",
# c5: "2551",
# c6: "9311",
# options: {
# url_append: "comscorekw=GTCSID_AUTOMOTIVE_RESOURCES"
# }
# },
# script: ".scorecardresearch.com/cs/7849854/beacon.js"
# }
# },
# reviews: [
# ],
# feedbackSummary: [
# ],
# csrfToken: "Mg3T7yaQgXd8dc1KRKjBg2ggwbIud5NNQwumf6737A8angGiF2hn8DMI%2F7lTYiX02f5Dul2SCcfgwI6d%2BFlZB7LUzUfkLQY7QbE6yJdIMjPdReJwx3wnUsulsG3XzTKbc2dAp0GhU%2FTf0cSKZXhzvK2VFiIhbtQVYnCaEonsMgqlBVwBpXRG%2B8GyF%2FuA04GOaS129Y%2Bj5RrETkxTQ0%2BYD0GpljvbCdJQCktMdE8R%2BLHHWUWxl%2BjWKW39KV%2FFi5iGAee64YYigVwQeSRntQEbCdgtjUKEVPJUO2qQt6c6bqw%3D"
# };
# </script>
# <script async="" src="https://cdn.adsafeprotected.com/iasPET.1.js"></script>
# <script async="async" src="https://www.google.com/adsense/search/ads.js"></script>
# <script async="" src="//gumtree-com-uk.videoplayerhub.com/galleryplayer.js"></script>
# <script>
# Gum.device = "desktop";
# (function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(
# arguments)},g[o]['t']=1*new Date})(window,'_googCsa');
# Gum.ads.adsense.category = {
# l1Category: "cars-vans-motorbikes",
# l2Category: 'cars',
# };
# Gum.ads.adsense.resultSize = 25;
# Gum.ads.adsense.pageOptions = {
# adPage: 1,
# pubId: 'gumtree-com-browse',
# query: 'Motors Cars',
# adtest: 'off',
# channel: '0_w_brl_2551_9311_x_1_x_x_x',
# linkTarget: '_blank',
# };
# Gum.ads.adsense.slots = [
# {
# id: 'slot12',
# maxTop: 1,
# colorAdBorder: '#d6d6d6'
# },
# {
# id: 'slot15',
# number: 4
# ,
# colorAdBorder: '#d6d6d6'
# }
# ];Gum.ads.display.pageType = "ResultsBrowse";
# Gum.ads.display.slots["lSkyB"] = {
# "defaultDims": [160,600],
# "mapping": [{screenSize: ['l','xl'], adSize: [[160, 600]], bidders: {rubicon: {zoneId: 463814, biddableSizes: [[160, 600]]}, openx: {unit: 538641011, biddableSizes: [[160, 600]]}, appnexus: {placementId: 10881395, biddableSizes: [[160, 600]]}, criteo: {zoneId: 813964, biddableSizes: [[160, 600]]}, ix: {siteId: '208977', size: [160, 600], biddableSizes: [[160, 600]]}, pubmatic: {adSlot: 'srp_bottom@160x600', biddableSizes: [[160, 600]]}}}, {screenSize: ['xxl'], adSize: [[300, 250],[300,600]], bidders: {rubicon: {zoneId: 463814, biddableSizes: [[300, 250], [300,600]]}, openx: {unit: 538641011, biddableSizes: [[300, 250], [300,600]]}, appnexus: {placementId: 10881395, biddableSizes: [[300, 250], [300,600]]}, criteo: {zoneId: 813965, biddableSizes: [[300,600]]}, ix: {siteId: '208977', size: [300, 600], biddableSizes: [[300,600]]}, pubmatic: {adSlot: 'srp_bottom@300x600', biddableSizes: [[300,600]]}, aol: {placement: 6542180, biddableSizes: [[300,600]]}}}],
# "adUnit": {
# "s": "/5144/desktop/srp/bottomLeft/cars-vans-motorbikes",
# "xl": "/5144/desktop/srp/bottomLeft/cars-vans-motorbikes",
# "xs": "/5144/desktop/srp/bottomLeft/cars-vans-motorbikes",
# "l": "/5144/desktop/srp/bottomLeft/cars-vans-motorbikes",
# "m": "/5144/desktop/srp/bottomLeft/cars-vans-motorbikes",
# "xxl": "/5144/desktop/srp/bottomLeft/cars-vans-motorbikes",
# },
# "slotId": "lSkyB"
# , "targeting": {
# 'pos': 'bottom'
# }
# };
# Gum.ads.display.slots["lSkyT"] = {
# "defaultDims": [160,600],
# "mapping": [{screenSize: ['l','xl'], adSize: [[160, 600]], bidders: {rubicon: {zoneId: 463764, biddableSizes: [[160, 600]]}, openx: {unit: 538641012, biddableSizes: [[160, 600]]}, appnexus: {placementId: 10881387, biddableSizes: [[160, 600]]}, criteo: {zoneId: 813951, biddableSizes: [[160, 600]]}, ix: {siteId: '208972', size: [160, 600], biddableSizes: [[160, 600]]}, pubmatic: {adSlot: 'srp_middle@160x600', biddableSizes: [[160, 600]]}, aol: {placement: 6542187, biddableSizes: [[160, 600]]}}}, {screenSize: ['xxl'], adSize: [[300, 250],[300,600]], bidders: {rubicon: {zoneId: 463764, biddableSizes: [[300, 250], [300,600]]}, openx: {unit: 538641012, biddableSizes: [[300, 250], [300,600]]}, appnexus: {placementId: 10881387, biddableSizes: [[300, 250], [300,600]]}, criteo: {zoneId: 1408820, biddableSizes: [[300, 250], [300,600]]}, ix: {siteId: '208972', size: [300, 600], biddableSizes: [[300,600]]}, pubmatic: {adSlot: 'srp_topLeft@300x600', biddableSizes: [[300,600]]}, aol: {placement: 6660465, biddableSizes: [[300, 250], [300,600]]}}}],
# "adUnit": {
# "s": "/5144/desktop/srp/topLeft/cars-vans-motorbikes",
# "xl": "/5144/desktop/srp/topLeft/cars-vans-motorbikes",
# "xs": "/5144/desktop/srp/topLeft/cars-vans-motorbikes",
# "l": "/5144/desktop/srp/topLeft/cars-vans-motorbikes",
# "m": "/5144/desktop/srp/topLeft/cars-vans-motorbikes",
# "xxl": "/5144/desktop/srp/topLeft/cars-vans-motorbikes",
# },
# "slotId": "lSkyT"
# , "targeting": {
# 'pos': 'middle'
# }
# };
# Gum.ads.display.slots["integratedMpu"] = {
# "defaultDims": [300,250],
# "mapping": [{screenSize: ['xs','s'], adSize: [[300,250],'fluid'], bidders: {rubicon: {zoneId: 463748, biddableSizes: [[300,250]]}, openx: {unit: 538641044, biddableSizes: [[300,250]]}, appnexus: {placementId: 10881385, biddableSizes: [[300,250]]}, criteo: {zoneId: 813948, biddableSizes: [[300,250]]}, ix: {siteId: '208970', size: [300, 250], biddableSizes: [[300,250]]}, pubmatic: {adSlot: 'srp_middle1@300x250', biddableSizes: [[300,250]]}, aol: {placement: 6542179, biddableSizes: [[300,250]]}}}, {screenSize: ['m','l','xl','xxl'], adSize: [[300,250],[728,90],'fluid'], bidders: {rubicon: {zoneId: 463748, biddableSizes: [[300,250], [728,90]]}, openx: {unit: 538641044, biddableSizes: [[300,250], [728,90]]}, appnexus: {placementId: 10881385, biddableSizes: [[300,250], [728,90]]}, criteo: {zoneId: 813948, biddableSizes: [[300,250]]}, ix: {siteId: '208970', size: [300, 250], biddableSizes: [[300,250]]}, pubmatic: {adSlot: 'srp_middle1@300x250', biddableSizes: [[300,250]]}, aol: {placement: 6542179, biddableSizes: [[300,250]]}}}],
# "adUnit": {
# "s": "/5144/desktop/srp/middle1/cars-vans-motorbikes",
# "xl": "/5144/desktop/srp/middle1/cars-vans-motorbikes",
# "xs": "/5144/desktop/srp/middle1/cars-vans-motorbikes",
# "l": "/5144/desktop/srp/middle1/cars-vans-motorbikes",
# "m": "/5144/desktop/srp/middle1/cars-vans-motorbikes",
# "xxl": "/5144/desktop/srp/middle1/cars-vans-motorbikes",
# },
# "slotId": "integratedMpu"
# , "targeting": {
# 'pos': 'middle1'
# }
# };
# Gum.ads.display.slots["rSkyT"] = {
# "defaultDims": [160,600],
# "mapping": [{screenSize: ['xl'], adSize: [[160, 600]], bidders: {rubicon: {zoneId: 463738, biddableSizes: [[160, 600]]}, openx: {unit: 538641025, biddableSizes: [[160, 600]]}, appnexus: {placementId: 10881384, biddableSizes: [[160, 600]]}, criteo: {zoneId: 813944, biddableSizes: [[160, 600]]}, ix: {siteId: '208969', size: [160, 600], biddableSizes: [[160, 600]]}, pubmatic: {adSlot: 'srp_top@160x600', biddableSizes: [[160, 600]]}}}, {screenSize: ['xxl'], adSize: [[300, 250],[300,600],[300,1050]], bidders: {rubicon: {zoneId: 463738, biddableSizes: [[300, 250], [300,600]]}, openx: {unit: 538641025, biddableSizes: [[300, 250], [300,600]]}, appnexus: {placementId: 10881384, biddableSizes: [[300, 250], [300,600]]}, criteo: {zoneId: 813947, biddableSizes: [[300,600]]}, ix: {siteId: '208969', size: [300, 600], biddableSizes: [[300,600]]}, pubmatic: {adSlot: 'srp_top@300x600', biddableSizes: [[300,600]]}, aol: {placement: 6542188, biddableSizes: [[300,600]]}}}],
# "adUnit": {
# "s": "/5144/desktop/srp/topRight/cars-vans-motorbikes",
# "xl": "/5144/desktop/srp/topRight/cars-vans-motorbikes",
# "xs": "/5144/desktop/srp/topRight/cars-vans-motorbikes",
# "l": "/5144/desktop/srp/topRight/cars-vans-motorbikes",
# "m": "/5144/desktop/srp/topRight/cars-vans-motorbikes",
# "xxl": "/5144/desktop/srp/topRight/cars-vans-motorbikes",
# },
# "slotId": "rSkyT"
# , "targeting": {
# 'pos': 'top'
# }
# };
# Gum.ads.display.slots["tBanner"] = {
# "defaultDims": [728,90],
# "mapping": [{screenSize: ['xs','s'], adSize: [[2000,255]]}, {screenSize: ['m'], adSize: [[728, 90],[2000,255]], bidders: {rubicon: {zoneId: 463730, biddableSizes: [[728, 90]]}, openx: {unit: 538641024, biddableSizes: [[728, 90]]}, appnexus: {placementId: 10881383, biddableSizes: [[728, 90]]}}}, {screenSize: ['l','xl','xxl'], adSize: [[728, 90],[970,90],[970,250],[2000,255]], bidders: {rubicon: {zoneId: 463730, biddableSizes: [[728, 90], [970,250]]}, openx: {unit: 538641024, biddableSizes: [[728, 90], [970,250]]}, appnexus: {placementId: 10881383, biddableSizes: [[728, 90], [970,250]]}, criteo: {zoneId: 813889, biddableSizes: [[970,250]]}, ix: {siteId: '208968', size: [970, 250], biddableSizes: [[970,250]]}, pubmatic: {adSlot: 'srp_top@970x250', biddableSizes: [[970,250]]}, aol: {placement: 6542182, biddableSizes: [[970,250]]}}}],
# "adUnit": {
# "s": "/5144/desktop/srp/top/cars-vans-motorbikes",
# "xl": "/5144/desktop/srp/top/cars-vans-motorbikes",
# "xs": "/5144/desktop/srp/top/cars-vans-motorbikes",
# "l": "/5144/desktop/srp/top/cars-vans-motorbikes",
# "m": "/5144/desktop/srp/top/cars-vans-motorbikes",
# "xxl": "/5144/desktop/srp/top/cars-vans-motorbikes",
# },
# "slotId": "tBanner"
# , "targeting": {
# 'pos': 'top'
# }
# };
# Gum.ads.display.slots["baseMpu"] = {
# "defaultDims": [300,250],
# "mapping": [{screenSize: ['m','l'], adSize: [[300, 250],[300,600]], bidders: {rubicon: {zoneId: 463814, biddableSizes: [[300, 250], [300,600]]}, openx: {unit: 538641011, biddableSizes: [[300, 250], [300,600]]}, appnexus: {placementId: 10881395, biddableSizes: [[300, 250], [300,600]]}, criteo: {zoneId: 813965, biddableSizes: [[300,600]]}, ix: {siteId: '208977', size: [300, 600], biddableSizes: [[300,600]]}, pubmatic: {adSlot: 'srp_bottom@300x600', biddableSizes: [[300,600]]}, aol: {placement: 6542180, biddableSizes: [[300,600]]}}}],
# "adUnit": {
# "s": "/5144/desktop/srp/bottom/cars-vans-motorbikes",
# "xl": "/5144/desktop/srp/bottom/cars-vans-motorbikes",
# "xs": "/5144/desktop/srp/bottom/cars-vans-motorbikes",
# "l": "/5144/desktop/srp/bottom/cars-vans-motorbikes",
# "m": "/5144/desktop/srp/bottom/cars-vans-motorbikes",
# "xxl": "/5144/desktop/srp/bottom/cars-vans-motorbikes",
# },
# "slotId": "baseMpu"
# , "targeting": {
# 'pos': 'bottom'
# }
# };
# Gum.ads.display.slots["textLink"] = {
# "defaultDims": [330,75],
# "mapping": [{screenSize: ['xs','s'], adSize: [[330,75],'fluid']}, {screenSize: ['m','l','xl','xxl'], adSize: [[665,35],'fluid']}],
# "adUnit": {
# "s": "/5144/desktop/srp/topTextlink/cars-vans-motorbikes",
# "xl": "/5144/desktop/srp/topTextlink/cars-vans-motorbikes",
# "xs": "/5144/desktop/srp/topTextlink/cars-vans-motorbikes",
# "l": "/5144/desktop/srp/topTextlink/cars-vans-motorbikes",
# "m": "/5144/desktop/srp/topTextlink/cars-vans-motorbikes",
# "xxl": "/5144/desktop/srp/topTextlink/cars-vans-motorbikes",
# },
# "slotId": "textLink"
# , "targeting": {
# 'pos': 'top'
# }
# };
# Gum.ads.display.slots["pixel"] = {
# "defaultDims": [1,1],
# "mapping": [{screenSize: ['xs','s','m','l','xl','xxl'], adSize: [[1,1]]}],
# "adUnit": {
# "s": "/5144/desktop/srp/pixel/cars-vans-motorbikes",
# "xl": "/5144/desktop/srp/pixel/cars-vans-motorbikes",
# "xs": "/5144/desktop/srp/pixel/cars-vans-motorbikes",
# "l": "/5144/desktop/srp/pixel/cars-vans-motorbikes",
# "m": "/5144/desktop/srp/pixel/cars-vans-motorbikes",
# "xxl": "/5144/desktop/srp/pixel/cars-vans-motorbikes",
# },
# "slotId": "pixel"
# , "targeting": {
# 'pos': 'pixel'
# }
# };
# Gum.ads.display.slots["rSkyB"] = {
# "defaultDims": [160,600],
# "mapping": [{screenSize: ['xl'], adSize: [[160, 600]]}, {screenSize: ['xxl'], adSize: [[300, 250],[300,600],[300,1050]], bidders: {rubicon: {zoneId: 463770, biddableSizes: [[300, 250], [300,600]]}, openx: {unit: 538641052, biddableSizes: [[300, 250], [300,600]]}, appnexus: {placementId: 10881388, biddableSizes: [[300, 250], [300,600]]}, criteo: {zoneId: 813952, biddableSizes: [[300,600]]}, ix: {siteId: '208973', size: [300, 600], biddableSizes: [[300,600]]}, pubmatic: {adSlot: 'srp_floating-bottom@300x600', biddableSizes: [[300,600]]}, aol: {placement: 6542181, biddableSizes: [[300,600]]}}}],
# "adUnit": {
# "s": "/5144/desktop/srp/bottomRight/cars-vans-motorbikes",
# "xl": "/5144/desktop/srp/bottomRight/cars-vans-motorbikes",
# "xs": "/5144/desktop/srp/bottomRight/cars-vans-motorbikes",
# "l": "/5144/desktop/srp/bottomRight/cars-vans-motorbikes",
# "m": "/5144/desktop/srp/bottomRight/cars-vans-motorbikes",
# "xxl": "/5144/desktop/srp/bottomRight/cars-vans-motorbikes",
# },
# "slotId": "rSkyB"
# , "targeting": {
# 'pos': 'floating-bottom'
# }
# };
# Gum.ads.display.slots["integratedListing"] = {
# "defaultDims": [728,200],
# "mapping": [{screenSize: ['xs','s'], adSize: [[320,50],[300,250],[320,100]], bidders: {rubicon: {zoneId: 463756, biddableSizes: [[300,250]]}, openx: {unit: 538641047, biddableSizes: [[300,250]]}, appnexus: {placementId: 10881386, biddableSizes: [[300,250]]}, criteo: {zoneId: 813950, biddableSizes: [[300,250]]}, ix: {siteId: '208971', size: [300, 250], biddableSizes: [[300,250]]}, pubmatic: {adSlot: 'srp_middle2@300x250', biddableSizes: [[300,250]]}, aol: {placement: 6542183, biddableSizes: [[300,250]]}}}, {screenSize: ['m','l','xl','xxl'], adSize: [[728,200],[300,250],[728,90],'fluid'], bidders: {rubicon: {zoneId: 463756, biddableSizes: [[300,250], [728,90]]}, openx: {unit: 538641047, biddableSizes: [[300,250], [728,90]]}, appnexus: {placementId: 10881386, biddableSizes: [[300,250], [728,90]]}, criteo: {zoneId: 813950, biddableSizes: [[300,250]]}, ix: {siteId: '208971', size: [300, 250], biddableSizes: [[300,250]]}, pubmatic: {adSlot: 'srp_middle2@300x250', biddableSizes: [[300,250]]}, aol: {placement: 6542183, biddableSizes: [[300,250]]}}}],
# "adUnit": {
# "s": "/5144/desktop/srp/middle2/cars-vans-motorbikes",
# "xl": "/5144/desktop/srp/middle2/cars-vans-motorbikes",
# "xs": "/5144/desktop/srp/middle2/cars-vans-motorbikes",
# "l": "/5144/desktop/srp/middle2/cars-vans-motorbikes",
# "m": "/5144/desktop/srp/middle2/cars-vans-motorbikes",
# "xxl": "/5144/desktop/srp/middle2/cars-vans-motorbikes",
# },
# "slotId": "integratedListing"
# , "targeting": {
# 'pos': 'middle2'
# }
# };
# Gum.ads.display.resultSize = 17045;
# Gum.ads.display.l1Category = "cars-vans-motorbikes";
# Gum.ads.display.l2Category = "cars";
# Gum.ads.display.config = {
# "name": '/5144/gtr.cars/cars',
# "ppid": '',
# "prebid": {
# "bidders": {
# "aol": {
# "network": 4883.1,
# "server": "adserver-eu.adtech.advertising.com",
# "keyValues": {
# category: "cars-vans-motorbikes",
# category_2: "cars",
# }
# },
# "rubicon": {
# "accountId": 13948,
# "siteId": 98816,
# visitor: {
# search: ""
# },
# inventory: {
# category: "cars-vans-motorbikes",
# category_2: "cars",
# experiments: [ 'GTALL-24856-D', 'GTALL-19721-A', 'GTALL-25488-B', 'GTALL-24237-B', 'GTALL-17502-B', 'GTALL-17844-B', 'GTALL-18911-A', 'GTALL-26059-B', 'GTALL-26257-A', 'GTALL-25740-B', 'GTALL-23001-A', 'GTALL-26399-C', 'GTALL-21241-B', 'GTALL-26394-B', 'GTALL-25681-A', 'GTALL-24052-B', 'GTALL-26051-A', 'GTALL-16230-A', 'GTALL-17010-B', 'GTALL-24788-C', 'GTALL-22323-B', 'GTALL-24568-B', 'GTALL-23339-B', 'GTALL-25159-B', 'GTALL-20842-B', 'GTALL-19434-B', 'GTALL-25238-B', 'GTALL-25975-B', 'GTALL-19559-A', 'GTALL-25498-B', 'GTALL-24761-B', 'GTALL-23034-B', 'GTALL-21395-B', 'GTALL-25493-A', 'GTALL-16805-B', 'GTALL-24180-B', 'GTALL-15996-A', 'GTALL-16886-B', 'GTALL-19291-B', 'GTALL-20779-A', 'GTALL-25508-B' ],
# },
# keywords: ""
# },
# "openx": {
# "delDomain": "//gumtreeuk-d.openx.net",
# customParams: {
# category: "cars-vans-motorbikes",
# category_2: "cars",
# keywords: ""
# }
# },
# "pubmatic": {
# "publisherId": "156407"
# },
# "appnexus": {}
# },
# "gaTrackingEnabled": false,
# "timeout": 1500
# },
# "targeting": {
# "ptg" : [ 'GTALL-24856-D', 'GTALL-19721-A', 'GTALL-25488-B', 'GTALL-24237-B', 'GTALL-17502-B', 'GTALL-17844-B', 'GTALL-18911-A', 'GTALL-26059-B', 'GTALL-26257-A', 'GTALL-25740-B', 'GTALL-23001-A', 'GTALL-26399-C', 'GTALL-21241-B', 'GTALL-26394-B', 'GTALL-25681-A', 'GTALL-24052-B', 'GTALL-26051-A', 'GTALL-16230-A', 'GTALL-17010-B', 'GTALL-24788-C', 'GTALL-22323-B', 'GTALL-24568-B', 'GTALL-23339-B', 'GTALL-25159-B', 'GTALL-20842-B', 'GTALL-19434-B', 'GTALL-25238-B', 'GTALL-25975-B', 'GTALL-19559-A', 'GTALL-25498-B', 'GTALL-24761-B', 'GTALL-23034-B', 'GTALL-21395-B', 'GTALL-25493-A', 'GTALL-16805-B', 'GTALL-24180-B', 'GTALL-15996-A', 'GTALL-16886-B', 'GTALL-19291-B', 'GTALL-20779-A', 'GTALL-25508-B' ],
# 'country': 'england',
# 'pt': 'ResultsSearch',
# 'g_hd': 'c482f98f7599247794cb0401cdf899c70a95042d77cd346eb95e15029ddff12d',
# 'page_type': 'browse',
# 'hn': 'gumtree.com',
# 'g_pn': '1',
# 'l2': 'cars',
# 'bkt': 'B25',
# 'env': 'prod',
# 'kw': '',
# 'platform': '-computer',
# 'g_cco': 'USED',
# 'ct': '9311',
# 'site': 'responsive',
# 'interaction': '1',
# 'region': 'london',
# 'device': '-computer',
# 'li': '0'
# }
# };
# Gum.ads.display.config.targeting.network = (
# navigator &&
# navigator.connection &&
# navigator.connection.effectiveType
# ) || 'unknown';Gum.ads.bing = {
# "keywords": "Motors+Cars",
# "ip": "81.109.24.246",
# };Gum.ads.partnership.parameters = {
# categoryHierarchy: [
# {
# "seoName": "cars-vans-motorbikes",
# "depth": 1,
# },
# {
# "seoName": "cars",
# "depth": 2,
# }
# ],
# location: {
# longitude: -0.129356,
# latitude: 51.507248,
# },
# attributes: [
# ]
# };
# Gum.ads.partnership.baseUrl = "https://gateway.gumtree.com/partnerships/standalone";
# </script>
# <script>
# ...
# </div>
# </div>
# </div>
# </div>
# </div>
# <aside class="srp-container-aside hide-fully-to-xl sponsored-mpufixed is-splitads" role="complementary">
# <div id="rskytCont">
# <div class="slots-container space-mbm" data-affix="channel:slots-container-rskytCont,className:is-affixed,match:rskytCont" id="slots-container-rskytCont">
# <div class="space-mbm" data-display-ad="" id="rSkyT"></div>
# <div class="hide-fully-to-xxl" data-display-ad="" id="rSkyT2"></div>
# </div>
# </div>
# <div id="rskybCont">
# <div class="slots-container space-mbm" data-affix="channel:slots-container-rskybCont,className:is-affixed,match:rskybCont" id="slots-container-rskybCont">
# <div class="space-mbm" data-display-ad="" id="rSkyB"></div>
# <div class="hide-fully-to-xxl" data-display-ad="" id="rSkyB2"></div>
# </div>
# </div>
# </aside> </div>
# </main>
# </section>
# <span class="hide-fully" data-l1-category="true">Motors</span>
# </div>
# <section>
# <div class="grid-container">
# <div class="grid-row">
# <div class="grid-col-12">
# <ul class="tabs-simple tabs-simple-light">
# <li>
# <a aria-controls="top-links-top-searches" aria-haspopup="true" class="tabs-simple-tab is-open" data-radiotoggle="channel:top-links,selfBroadcast:true,toggleSelf:true" href="#">
# Top searches
# </a>
# </li>
# <li>
# <a aria-controls="suggested-link-locations" aria-haspopup="true" class="tabs-simple-tab" data-radiotoggle="channel:top-links,selfBroadcast:true,toggleSelf:true" href="#">
# Top locations
# </a>
# </li>
# </ul>
# <div class="tabs-simple-bar">
# <div class="tabs-simple-bar-mask"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-container">
# <div class="grid-row">
# <div class="grid-col-10 grid-col-offset-1">
# <div aria-expanded="true" data-radiotoggle="channel:top-links,toggleSelf:true,className:hide-fully" id="top-links-top-searches">
# <h4 data-toggler="channel:top-links-local,
# className:is-open" role="button" tabindex="0">
# Top Searches in London
# <span aria-hidden="true" class="icn-dropdown iconu-xs"></span>
# </h4>
# <div class="hide-fully" data-toggler="channel:top-links-local,
# className:hide-fully,
# selfBroadcast:false">
# <ul class="bar-list txt-center txt-sub space-mbm">
# <li><a href="https://www.gumtree.com/cars/london/automatic">automatic cars</a></li>
# <li><a href="https://www.gumtree.com/cars/london/private">car</a></li>
# <li><a href="https://www.gumtree.com/cars/london/pco">pco cars</a></li>
# <li><a href="https://www.gumtree.com/cars/london/left+hand+drive">left hand drive cars</a></li>
# <li><a href="https://www.gumtree.com/cars/london/7+seater">7 seater automatic</a></li>
# <li><a href="https://www.gumtree.com/cars/london/bargain+cars">cheap cars</a></li>
# <li><a href="https://www.gumtree.com/cars/london/ford/fiesta">ford fiesta</a></li>
# <li><a href="https://www.gumtree.com/cars/london/hybrid-electric">electric hybrid</a></li>
# <li><a href="https://www.gumtree.com/cars/london/ford/focus">ford focus</a></li>
# <li><a href="https://www.gumtree.com/cars/london/volkswagen/polo">volkswagen polo</a></li>
# <li><a href="https://www.gumtree.com/cars/london/classic+cars">classic cars</a></li>
# <li><a href="https://www.gumtree.com/cars/london/damaged">damaged cars</a></li>
# <li><a href="https://www.gumtree.com/cars/london/smart">smart diesel</a></li>
# <li><a href="https://www.gumtree.com/cars/london/fiat/500">fiat 500</a></li>
# <li><a href="https://www.gumtree.com/cars/london/mini">mini west london</a></li>
# <li><a href="https://www.gumtree.com/cars/london/toyota/yaris/automatic">toyota yaris</a></li>
# <li><a href="https://www.gumtree.com/cars/london/bmw">bmw</a></li>
# <li><a href="https://www.gumtree.com/cars/london/nissan/qashqai">nissan qashqai</a></li>
# <li><a href="https://www.gumtree.com/cars/london/4x4">4x4</a></li>
# <li><a href="https://www.gumtree.com/cars/london/toyota">toyota</a></li>
# <li><a href="https://www.gumtree.com/cars/london/audi">audi cars</a></li>
# <li><a href="https://www.gumtree.com/cars/london/volkswagen/polo/automatic">volkswagen polo</a></li>
# <li><a href="https://www.gumtree.com/cars/london/small+car">cars</a></li>
# <li><a href="https://www.gumtree.com/cars/london/swap">car</a></li>
# <li><a href="https://www.gumtree.com/cars/london/mercedes-benz/a-class">mercedes a class</a></li>
# <li><a href="https://www.gumtree.com/cars/london/jeep">jeep</a></li>
# <li><a href="https://www.gumtree.com/cars/london/automatic+hatchback">automatic hatchback car</a></li>
# <li><a href="https://www.gumtree.com/cars/london/toyota/yaris">toyota yaris diesel</a></li>
# <li><a href="https://www.gumtree.com/cars/london/mini/automatic">mini cooper</a></li>
# <li><a href="https://www.gumtree.com/cars/london/audi/a3">audi a3</a></li>
# <li><a href="https://www.gumtree.com/cars/london/bmw/1-series">bmw 1 series</a></li>
# <li><a href="https://www.gumtree.com/cars/london/jeep/wrangler">jeep wrangler</a></li>
# <li><a href="https://www.gumtree.com/cars/london/fiat/500/automatic">fiat 500</a></li>
# <li><a href="https://www.gumtree.com/cars/london/toyota/prius">toyota prius wheels</a></li>
# <li><a href="https://www.gumtree.com/cars/london/volkswagen/golf">volkswagen golf petrol cars</a></li>
# <li><a href="https://www.gumtree.com/cars/london/honda/civic">honda civic</a></li>
# </ul>
# </div>
# </div>
# <div aria-expanded="false" class="hide-fully" data-radiotoggle="channel:top-links,toggleSelf:true,enableContainerActive:true,className:hide-fully" id="suggested-link-locations">
# <ul class="bar-list txt-center txt-sub space-mbm">
# <li><a href="https://www.gumtree.com/cars/bristol">cars in Bristol</a></li>
# <li><a href="https://www.gumtree.com/cars/manchester">cars in Manchester</a></li>
# <li><a href="https://www.gumtree.com/cars/herefordshire">cars hereford in Herefordshire</a></li>
# <li><a href="https://www.gumtree.com/cars/somerset">cars in Somerset</a></li>
# <li><a href="https://www.gumtree.com/cars/cornwall">cars in Cornwall</a></li>
# <li><a href="https://www.gumtree.com/cars/norfolk">cars in Norfolk</a></li>
# <li><a href="https://www.gumtree.com/cars/dorset">cars in Dorset</a></li>
# <li><a href="https://www.gumtree.com/cars/worcestershire">cars worcester in Worcestershire</a></li>
# <li><a href="https://www.gumtree.com/cars/devon">cars in in Devon</a></li>
# <li><a href="https://www.gumtree.com/cars/manchester/cars+for+sale">cars in Manchester</a></li>
# <li><a href="https://www.gumtree.com/cars/cumbria">cars in Cumbria</a></li>
# <li><a href="https://www.gumtree.com/cars/wiltshire">cars in Wiltshire</a></li>
# <li><a href="https://www.gumtree.com/cars/suffolk">cars in Suffolk</a></li>
# <li><a href="https://www.gumtree.com/cars/warwickshire">warwick car sales in Warwickshire</a></li>
# <li><a href="https://www.gumtree.com/cars/hampshire">cars in Hampshire</a></li>
# <li><a href="https://www.gumtree.com/cars/oxfordshire">cars in Oxfordshire</a></li>
# <li><a href="https://www.gumtree.com/cars/hertfordshire">cars in in Hertfordshire</a></li>
# <li><a href="https://www.gumtree.com/cars/berkshire">new cars in Berkshire</a></li>
# <li><a href="https://www.gumtree.com/cars/kent">cars in Kent</a></li>
# <li><a href="https://www.gumtree.com/cars/surrey">car in in Surrey</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="footer-banner-container">
# <div class="data-lazy image-app-banner image-app-banner-footer image-app-banner--with-description" data-bg="url(https://www.gumtree.com/static/1/resources/assets/rwd/images/orphans/b7ace698b862c8521f8ec2f3.Phone_mockup_min.png)">
# <div class="image-app-banner-content">
# <h3 class="image-app-banner-title">Buy and sell in a snap</h3>
# <p class="image-app-banner-desc">Get the app for the best Gumtree experience</p>
# </div>
# <div class="image-app-banner-store-buttons">
# <a class="image-app-banner-store-button" data-analytics="gaEvent:AppDownloadBegin, gaLabel:{label: footer_banner}, broadcastOptions:{defer:true,event:click}" href="https://app.adjust.com/ez1o5rv?campaign=Footer%20Banner&amp;adgroup=Global&amp;creative=V1&amp;redirect=https://itunes.apple.com/gb/app/gumtree/id487946174?mt=8">
# <span class="hide-visually">iOS App</span>
# <img alt="Available on the App Store" src="https://www.gumtree.com/static/1/resources/assets/rwd/images/svg/d0558d91063038236b60e3ef.App_Store_Badge.svg"/>
# </a>
# <a class="image-app-banner-store-button" data-analytics="gaEvent:AppDownloadBegin, gaLabel:{label: footer_banner}, broadcastOptions:{defer:true,event:click}" href="https://app.adjust.com/ez1o5rv?campaign=Footer%20Banner&amp;adgroup=Global&amp;creative=V1&amp;redirect=https://play.google.com/store/apps/details?id=com.gumtree.android&amp;hl=en_GB">
# <span class="hide-visually">Android App</span>
# <img alt="Available on the App Store" src="https://www.gumtree.com/static/1/resources/assets/rwd/images/svg/2961d6a9fb7950bd9b994027.google-play-badge.svg"/>
# </a>
# </div>
# </div>
# <footer class="footer">
# <div class="grid-container">
# <nav class="grid-row footer-primary-navigation" role="navigation">
# <div class="footer-links-list grid-col-10 grid-col-s-6 grid-col-m-3 grid-col-l-2 grid-col-push-1 grid-col-s-push-1">
# <h4 class="footer-heading" role="button">
# About Us
# </h4>
# <ul class="footer-primary-links">
# <li>
# <a data-q="about-us" href="https://www.gumtree.com/info/life/about-us/">About Gumtree</a>
# </li>
# <li>
# <a data-q="advertise-with-us" href="https://www.gumtree.com/info/life/advertise-with-us/">Advertise With Us</a>
# </li>
# <li>
# <a data-q="careers" href="https://www.gumtree.com/careers">Careers</a>
# </li>
# <li>
# <a data-q="media" href="https://www.gumtree.com/info/life/media/">Media</a>
# </li>
# <li>
# <a data-q="press" href="https://www.gumtree.com/info/life/press-pr/" target="_top">Press</a>
# </li>
# </ul>
# </div>
# <div class="footer-links-list grid-col-10 grid-col-s-6 grid-col-m-3 grid-col-l-2 grid-col-push-1 grid-col-s-push-1">
# <h4 class="footer-heading" role="button">
# Help &amp; Contact
# </h4>
# <ul class="footer-primary-links">
# <li>
# <a data-q="faq" href="https://help.gumtree.com/s/basics">FAQs</a>
# </li>
# <li>
# <a data-q="safety-advice" href="https://help.gumtree.com/s/safety">Safety</a>
# </li>
# <li>
# <a data-q="help-me-guides" href="https://help.gumtree.com/s/policies">Policies</a>
# </li>
# <li>
# <a data-q="contact-us" href="https://help.gumtree.com/s/">Contact Us</a>
# </li>
# <li>
# <a data-q="insurance" href="https://www.gumtree.com/insurance">Insurance</a>
# </li>
# </ul>
# </div>
# <div class="footer-links-list grid-col-10 grid-col-s-6 grid-col-m-3 grid-col-l-2 grid-col-push-1 grid-col-s-push-1">
# <h4 class="footer-heading" role="button">
# More From Us
# </h4>
# <ul class="footer-primary-links">
# <li>
# <a data-q="motors-hub" href="https://www.gumtree.com/info/cars/">Car Guides</a>
# </li>
# <li>
# <a data-q="gumtree-guides" href="https://www.gumtree.com/info/life/">Gumtree Life</a>
# </li>
# <li>
# <a data-q="car-price-index" href="https://www.gumtree.com/content/car-price-index/">Car Price Index</a>
# </li>
# <li>
# <a data-q="sell-my-car" href="https://www.gumtree.com/sell-my-car">Sell My Car</a>
# </li>
# <li>
# <a data-q="upcycle-revolution" href="https://www.gumtree.com/content/upcycling-hub/">Upcycle Revolution</a>
# </li>
# <li>
# <a data-q="popular-searches" href="https://www.gumtree.com/popular-search">Popular Searches</a>
# </li>
# </ul>
# </div>
# <div class="footer-links-list grid-col-10 grid-col-s-6 grid-col-m-3 grid-col-l-2 grid-col-push-1 grid-col-s-push-1">
# <h4 class="footer-heading" role="button">
# Mobile Apps
# </h4>
# <ul class="footer-primary-links">
# <li>
# <div class="grid-row space-mtxs">
# <div class="grid-col-12 space-mbxs">
# <a data-analytics="gaEvent:AppDownloadBegin, gaLabel:{label: android_footer}" data-q="mobile-apps" href="https://app.adjust.com/ez1o5rv?campaign=App%20Store%20Button&amp;adgroup=Global%20Footer&amp;creative=V1&amp;redirect=https://itunes.apple.com/gb/app/gumtree/id487946174?mt=8" target="_blank">
# <span class="hide-visually">iOS App</span>
# <img alt="Available on the App Store" src="https://www.gumtree.com/static/1/resources/assets/rwd/images/svg/d0558d91063038236b60e3ef.App_Store_Badge.svg"/>
# </a>
# </div>
# <div class="grid-col-12 space-mbxs">
# <a data-analytics="gaEvent:AppDownloadBegin, gaLabel:{label: android_footer}" data-q="mobile-apps" href="https://app.adjust.com/ez1o5rv?campaign=App%20Store%20Button&amp;adgroup=Global%20Footer&amp;creative=V1&amp;redirect=https://play.google.com/store/apps/details?id=com.gumtree.android&amp;hl=en_GB" target="_blank">
# <span class="hide-visually">Android App</span>
# <img alt="Available on the App Store" src="https://www.gumtree.com/static/1/resources/assets/rwd/images/svg/2961d6a9fb7950bd9b994027.google-play-badge.svg"/>
# </a>
# </div>
# </div>
# </li>
# <li>
# <a data-q="mobile-apps" href="https://www.gumtree.com/apps">More About Our Apps</a>
# </li>
# </ul>
# </div>
# </nav>
# <hr class="footer-hr grid-col-l-10 grid-col-offset-l-1 grid-col-l-push-1"/>
# <div class="footer-actions grid-row">
# <div class="footer-social grid-col-m-6 grid-col-l-5 grid-col-l-push-1">
# <div class="footer-social-wrapper">
# <h4 class="footer-heading txt-center">Follow Gumtree</h4>
# <ul class="hide-on-gesture footer-social-buttons">
# <li data-likebuttons="channel:facebook">
# <span class="footer-social-buttons-text"><span class="icn-facebook"></span> Like</span>
# <span class="footer-social-buttons-link">
# <span class="fb-like" data-action="like" data-href="https://www.facebook.com/gumtree" data-layout="button" data-share="false" data-show-faces="false">
# </span>
# </span>
# <span class="hide-visually">Like gumtree.com on Facebook</span>
# </li>
# <li data-likebuttons="channel:twitter">
# <span class="footer-social-buttons-text"><span class="icn-twitter"></span> Tweet</span>
# <span class="footer-social-buttons-link">
# <a class="twitter-follow-button" data-show-count="false" data-show-screen-name="false" href="https://twitter.com/gumtree"></a>
# </span>
# <span class="hide-visually">Follow gumtree.com on Twitter</span>
# </li>
# <li data-likebuttons="channel:pinterest">
# <span class="footer-social-buttons-text"><span class="icn-circ-pinterest"></span> Pin It</span>
# <span class="footer-social-buttons-link">
# <a data-pin-do="buttonFollow" href="http://www.pinterest.com/gumtreeuk/">Pin It</a>
# </span>
# <span class="hide-visually">Follow gumtree.com on Pinterest</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="footer-global-sites grid-col-m-6 grid-col-l-5 grid-col-l-push-1">
# <div class="footer-global-sites-wrapper">
# <h4 class="footer-heading txt-center">Gumtree Partners</h4>
# <ul class="footer-global-sites-items hide-on-gesture">
# <li class="footer-global-sites-item">
# <a href="https://www.motors.co.uk/">
# <span class="footer-global-sites-item-text">
# Motors
# </span>
# </a>
# </li>
# <li class="footer-global-sites-item">
# <a href="https://www.ebay.co.uk/">
# <span class="footer-global-sites-item-text">
# eBay.co.uk
# </span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <hr class="footer-hr grid-col-l-10 grid-col-offset-l-1 grid-col-l-push-1"/>
# <div class="grid-row">
# <div class="grid-col-12 grid-col-l-6 grid-col-l-offset-3">
# <p class="footer-copyright" data-q="copyright" role="contentinfo">
# © Copyright 2000-2022 Gumtree.com Limited. All rights reserved.
# <br/>
# <br/>
# Gumtree.com Limited is an Appointed Representative of Compare The Market Limited who
# is authorised and regulated by the Financial Conduct Authority.
# <br/>
# <br/>
# Gumtree.com Limited is an Introducer Appointed Representative of Zuto Limited who
# are authorised and regulated by the Financial Conduct Authority, FRN 452589. Zuto
# Limited is a credit broker, not a lender. Introductions are limited to motor
# finance.
# <br/>
# <br/>
# Gumtree.com Limited, registered in England and Wales with number 03934849, 27 Old Gloucester Street, London, WC1N 3AX, United Kingdom. VAT No. 345 7692 64.
# <br/>
# <br/>
# <a data-q="terms-of-use" href="https://www.gumtree.com/termsofuse">Terms of Use</a>,
# <a data-q="privacy-policy" href="https://www.gumtree.com/privacy_policy">Privacy Notice</a>,
# <a class="ot-sdk-show-settings" href="#privacy-settings" name="privacy-settings">Privacy Settings</a>,
# <a data-q="modern-slavery" href="https://www.gumtree.com/modern_slavery">Modern Slavery Statement</a> &amp;
# <a data-q="cookies-policy" href="https://www.gumtree.com/cookies">Cookies Policy</a>
# </p>
# </div>
# </div>
# </div>
# </footer>
# </div> </div>
# </div>
# <div id="gdpr-banner"></div>
# </body>
# </html>

# %% [markdown]
# ### Results

# %%
results = soup.find_all('article', {'class' : 'listing-maxi'})

# %%
len(results)
# Out:
# 30

# %%
results[1]
# Out:
# <article class="listing-maxi" data-q="ad-1426953836">
# <a class="listing-link" href="/p/peugeot/2017-peugeot-308-1.6-bluehdi-120-gt-line-5dr-estate-diesel-manual/1426953836">
# <div class="listing-side standout-listing">
# <div class="main-image">
# <div class="listing-thumbnail">
# <img alt="2017 Peugeot 308 1.6 BlueHDi 120 GT Line 5dr ESTATE Diesel Manual" class="data-lazy hide-fully-no-js main-image" src="https://i.ebayimg.com/00/s/NzY4WDEwMjQ=/z/exAAAOSwGjRiHfYe/$_99.JPG"/>
# <noscript><img alt="2017 Peugeot 308 1.6 BlueHDi 120 GT Line 5dr ESTATE Diesel Manual" src="https://i.ebayimg.com/00/s/NzY4WDEwMjQ=/z/exAAAOSwGjRiHfYe/$_99.JPG"/></noscript>
# <span class="ribbon-featured">
# <strong class="ribbon" data-q="featuredProduct"><span class="hide-visually">This ad is</span>Featured</strong>
# </span>
# <div class="listing-meta txt-sub">
# <ul class="inline-list txt-center">
# <li>
# <span aria-hidden="true" class="icn-camera iconu-xs"></span> 15<span class="hide-visually"> images</span>
# </li>
# <li>
# <span aria-hidden="true" class="icn-video iconu-xs"></span> 1<span class="hide-visually"> videos</span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="bottom-left-image">
# <div class="listing-thumbnail">
# <img alt="2017 Peugeot 308 1.6 BlueHDi 120 GT Line 5dr ESTATE Diesel Manual" class="data-lazy hide-fully-no-js bottom-left-image" data-src="https://i.ebayimg.com/00/s/NzY4WDEwMjQ=/z/3y0AAOSwJjdiHfYe/$_99.JPG" src=""/>
# <noscript><img alt="2017 Peugeot 308 1.6 BlueHDi 120 GT Line 5dr ESTATE Diesel Manual" src="https://i.ebayimg.com/00/s/NzY4WDEwMjQ=/z/3y0AAOSwJjdiHfYe/$_99.JPG"/></noscript>
# </div>
# </div>
# <div class="bottom-right-image">
# <div class="listing-thumbnail">
# <img alt="2017 Peugeot 308 1.6 BlueHDi 120 GT Line 5dr ESTATE Diesel Manual" class="data-lazy hide-fully-no-js bottom-right-image" data-src="https://i.ebayimg.com/00/s/NzY4WDEwMjQ=/z/BIkAAOSwYUliHfYe/$_99.JPG" src=""/>
# <noscript><img alt="2017 Peugeot 308 1.6 BlueHDi 120 GT Line 5dr ESTATE Diesel Manual" src="https://i.ebayimg.com/00/s/NzY4WDEwMjQ=/z/BIkAAOSwYUliHfYe/$_99.JPG"/></noscript>
# </div>
# </div>
# </div>
# <div class="listing-content">
# <h2 class="listing-title">
# 2017 Peugeot 308 1.6 BlueHDi 120 GT Line 5dr ESTATE Diesel Manual
# </h2>
# <div class="listing-location">
# <span class="truncate-line">
# Norbury, London
# </span>
# </div>
# <p class="listing-description txt-sub txt-tertiary truncate-paragraph standout-listing" data-toggler="channel:toggleDescription0,selfBroadcast:false">
# 2017 MODEL + GENUINE 59,000 MILES FROM NEW + VOSA VERIFIED MILEAGE + LONG MOT 02/12/2022 + CAT S REPAIRED 01/2020 + BLACK COLOUIR WITH HALF RECARO SPORT GT LEATHER SEATS WITH RED STITCHES + TOUCH SCREEN DISPLAY + SAT-NAVIGATION + REVERSE CAMERA + FR
# </p>
# <ul class="listing-attributes inline-list">
# <li>
# <span class="hide-visually">Year</span><span>2017</span>
# </li>
# <li>
# <span class="hide-visually">Mileage</span><span>59,000 miles</span>
# </li>
# <li>
# <span class="hide-visually">Seller type</span><span>Trade</span>
# </li>
# <li>
# <span class="hide-visually">Fuel type</span><span>Diesel</span>
# </li>
# <li>
# <span class="hide-visually">Engine size</span><span>1,560 cc</span>
# </li>
# </ul>
# <div class="listing-price-posted-container">
# <span class="listing-price">
# <strong class="h3-responsive">£7,985</strong>
# <span class="txt-tertiary txt-micro vat"></span>
# </span>
# <div class="listing-posted-date txt-sub">
# <span class="truncate-line txt-tertiary" data-q="listing-adAge">
# <span class="hide-visually">Ad posted </span>
# 1 day ago
# </span>
# </div>
# </div>
# </div>
# </a>
# <button class="listing-save-ad" data-analytics="gaEvent:WatchlistAddAttempt" data-savead="channel:savead-1426953836" data-token="Mg3T7yaQgXd8dc1KRKjBg2ggwbIud5NNQwumf6737A8angGiF2hn8DMI%2F7lTYiX02f5Dul2SCcfgwI6d%2BFlZB7LUzUfkLQY7QbE6yJdIMjPdReJwx3wnUsulsG3XzTKbc2dAp0GhU%2FTf0cSKZXhzvK2VFiIhbtQVYnCaEonsMgqlBVwBpXRG%2B8GyF%2FuA04GOaS129Y%2Bj5RrETkxTQ0%2BYD0GpljvbCdJQCktMdE8R%2BLHHWUWxl%2BjWKW39KV%2FFi5iGAee64YYigVwQeSRntQEbCdgtjUKEVPJUO2qQt6c6bqw%3D">
# <span class="hide-visually">
# Save this ad
# </span>
# <span aria-hidden="true" class="icn-empty-heart-berry"></span>
# </button>
# </article>

# %% [markdown]
# ### Target necessary data

# %%
# Name
# Location
# Price
# Car Details
# Car Link

# %% [markdown]
# #### Name

# %%
results[1].find('h2', {'class' : 'listing-title'}).get_text().strip()
# Out:
# '2017 Peugeot 308 1.6 BlueHDi 120 GT Line 5dr ESTATE Diesel Manual'

# %% [markdown]
# #### Location

# %%
results[1].find('span', {'class' : 'truncate-line'}).get_text().strip()
# Out:
# 'Norbury, London'

# %% [markdown]
# #### Price

# %%
results[1].find('strong', {'class' : 'h3-responsive'}).get_text()
# Out:
# '£7,985'

# %% [markdown]
# #### Car Link

# %%
#extract the relative URL

relative_url = results[1].find('a',{'class':'listing-link'}).get('href')

# %%
# provide the root element inside a variable

root_url = 'https://www.gumtree.com'

# %%
#combine root element and the relative URL

url_combined = root_url + relative_url

# %%
url_combined
# Out:
# 'https://www.gumtree.com/p/peugeot/2017-peugeot-308-1.6-bluehdi-120-gt-line-5dr-estate-diesel-manual/1426953836'

# %% [markdown]
# #### Details

# %%
results[1].find('ul', {'class' : 'listing-attributes inline-list'}).get_text(separator=' ' ).strip().replace(' \n \n \n ', ', ')
# Out:
# 'Year 2017, Mileage 59,000 miles, Seller type Trade, Fuel type Diesel, Engine size 1,560 cc'

# %% [markdown]
# ## Pagination - Scrape pages

# %% [markdown]
# ### Place everything together inside a for loop

# %%
car_name = []
car_location = []
car_price = []
car_link = []
car_details = []

for i in range(1,6):

    # website
    
    website = 'https://www.gumtree.com/cars/london/page' + str(i)
    
    
    # request
    
    response = requests.get(website)
        
    # soup object
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # results
    
    results = soup.find_all('article', {'class' : 'listing-maxi'})
    
    # loop through results
    
    for result in results:
        
            # name

        try:
            car_name.append(result.find('h2', {'class' : 'listing-title'}).get_text().strip())
        except:
            car_name.append('n/a')

        # location

        try:
            car_location.append(result.find('span', {'class' : 'truncate-line'}).get_text().strip())
        except:
            car_location.append('n/a')   

        # price

        try:
            car_price.append(result.find('strong', {'class' : 'h3-responsive'}).get_text())
        except:
            car_price.append('n/a')

        # car link

        try:
            car_link.append(result.find('a',{'class':'listing-link'}).get('href'))
        except:
            car_link.append('n/a')

        # car details

        try:
            car_details.append(result.find('ul', {'class' : 'listing-attributes inline-list'}).get_text(separator=' ' ).strip().replace(' \n \n \n ', ', '))
        except:
            car_details.append('n/a')

# %%
car_name
# Out:
# ['Mercedes-Benz, E CLASS, Saloon, 2018, Semi-Auto, 1950 (cc), 4 doors',
#  '2009 Land Rover Discovery 4 3.0 TD V6 GS Auto 4WD 5dr +7 Seats +Low Miles +1 For',
#  'BMW 4 SERIES COUPE 428i 241HP',
#  'Hounslow Tw',
#  'Mercedes-Benz A Class 2.1 A200d AMG Line (Premium Plus) 7G-DCT (s/s) 5dr',
#  'Mercedes-Benz, GLA, Estate, 2016, Semi-Auto, 1595 (cc), 5 doors',
#  '⭐2006 VOLKSWAGEN GOLF GTI 2.0 TFSI DSG⭐HPI CLEAR✔️LOW MILES✔️FULL FSH✔',
#  'BMW 2 Series Tourer 2.0 220i Luxury Active Tourer Petrol',
#  '2020 Ford Puma 1.0 EcoBoost Hybrid mHEV ST-Line 5dr Manual Hatchback Petrol Manu',
#  'Volkswagen Golf 1.4 TSI GT DSG 5dr Petrol',
#  '2018 Vauxhall Mokka X 1.4 ELITE NAV Auto Hatchback PETROL Automatic',
#  '2017 Audi A5 S5 Quattro 2dr Tiptronic Convertible Petrol Automatic',
#  'Toyota C-HR TOYOTA C-HR 1.8 Hybrid Excel 5dr CVT [Leather] Hybrid',
#  '2021 Ford Puma 1.0 EcoBoost Hybrid mHEV ST-Line X 5dr Hatchback Petrol Manual',
#  '2018 Kia Stonic 1.0 T-GDi 2 Manual Estate Petrol Manual',
#  '2019 Vauxhall Mokka X 1.4 ACTIVE Auto Hatchback PETROL Automatic',
#  'Peugeot 3008 1.5 BlueHDi GT Line Diesel',
#  'MERCEDES-BENZ GLE-CLASS 3.0L GLE 350 D 4MATIC AMG LINE PREMIUM PLUS 4d AUTO',
#  '2020 Hyundai Ioniq 38.3kWh Premium Hatchback 5dr Electric Auto (136 ps) Hatchbac',
#  'Mercedes CLA 2.2 200d AMG Line Diesel',
#  'Toyota AYGO 1.0 VVT-i x-cite 5dr Petrol',
#  '2020 MINI HATCHBACK 1.5 Cooper Sport II 3dr Auto Hatchback Petrol Automatic',
#  'Ford Edge 2.0 TDCi 210 Sport Powershift AWD Diesel',
#  'Nissan Qashqai 1.5 dCi Acenta Premium Diesel',
#  '2020 Honda HONDA E 35.5kWh Advance Hatchback 5dr Electric Auto (17in Alloy) (154',
#  '2020 Peugeot 308 1.5 BLUEHDI S/S ALLURE DIGITAL Auto Hatchback DIESEL Automatic',
#  '2019 Ford Fiesta 1.0 EcoBoost Zetec Navigation 5dr Manual Hatchback Petrol Manua',
#  '2021 Nissan Leaf 110kW 10 40kWh 5dr Auto Automatic Hatchback Electric Automatic',
#  'Ford Focus TITANIUM X',
#  'Renault Megane 1.5 dCi Expression+ Diesel',
#  '2015 Volkswagen Scirocco 2.0 TDi 184 BlueMotion Tech GT 3dr COUPE Diesel Manual',
#  'Vauxhall Astra 1.6 16v Exclusiv Euro 5 5dr Petrol',
#  'Renault Megane petrol 1.6cc 3dr 2010',
#  'MERCEDES SL320 (R129) FOR SALE',
#  'SEAT IBIZA TOCA PETROL Excellent condition drives like new',
#  '2017 Hyundai Kona 1.6T GDi Blue Drive Premium GT 5dr 4WD DCT Semi-Auto Hatchback',
#  'Nissan Qashqai 1.5 dCi Acenta Diesel',
#  'MERCEDES BENZ C180 AUTO / PETROL / ULEZ FREE / FULL SERVICE HISTORY / C CLASS / SALOON E / CHEAP CAR',
#  'Range rover vogue v8',
#  'Mercedes-Benz, E CLASS, Saloon, 2018, Semi-Auto, 1950 (cc), 4 doors',
#  'Mini one 2007 ulez free 100k',
#  'Bmw 325i se',
#  '2015 Volkswagen Polo 1.2 TSI BlueMotion Tech SE DSG (s/s) 5dr +20£Tax +Auto +ULE',
#  'Toyota Corolla 1.8 VVTL-i T Sport 3dr Petrol',
#  'Mercedes-Benz SL Class 5.0 SL500 Silver Arrow Limited Edition 2dr Petrol',
#  'Honda Civic 1.6 i-DTEC Black Edition 5dr Diesel',
#  '2019 Honda Jazz 1.3 i-VTEC SE Hatchback 5dr Petrol (s/s) (102 ps) Hatchback Petr',
#  'Mini Hatch 1.5 Cooper Chili Pack Petrol',
#  '2019 Ford Ecosport 5Dr ST-Line 1.0 125PS Hatchback Petrol Manual',
#  'Volkswagen Golf 1.4 TSI BlueMotion Tech Match DSG 5dr Stop/Start',
#  'Nissan Qashqai 1.5 dCi Tekna 5dr Diesel',
#  '2016 BMW 1 Series 118i [1.5] SE 5dr [Nav] HATCHBACK Petrol Manual',
#  '2019 Land Rover Range Rover Sport 2.0 P400e HSE Dynamic 5dr Auto SUV Petrol/Plu',
#  'Nissan Qashqai 1.6 dCi Tekna 5dr Diesel',
#  '2020 Ford Puma 1.0 EcoBoost Hybrid mHEV 155 ST-Line X 1st Ed 5dr Hatchback Petro',
#  'Volkswagen Tiguan 2.0 TDi 150 S 4Motion DSG Diesel',
#  'Renault Captur RENAULT CAPTUR 0.9 TCE 90 Iconic 5dr Petrol',
#  '2018 Nissan Juke 1.6 Tekna 5dr Xtronic Auto Hatchback Petrol Automatic',
#  '2019 Nissan Qashqai 1.3 DiG-T 160 N-Connecta 5dr DCT Semi-Auto Hatchback Petrol',
#  'Toyota Voxy 1.8 Hybrid 7 Seats MPV MPV Petrol/Electric Hybrid Automatic',
#  'BMW 5 SERIES **ULEZ ***BIG SPEC',
#  'Mercedes-Benz E Class 2.1 E250 CDI BlueEFFICIENCY SE 2dr Diesel',
#  'LHD 2016 Ford Kuga 2.0 TDCi automatic Titanium Individual',
#  '2012 FORD FOCUS 1.6 Zetec 5dr *Full Service History 7-Stamps, ONLY 32000 Miles*',
#  'Audi A6 Saloon 3.0 TDI Le Mans quattro 4dr Diesel',
#  'Vauxhall Mokka X 1.4 T Elite Petrol',
#  'Seat Arona 1.6 TDi Xcellence Lux EZ DSG Diesel',
#  'Ford Kuga 1.5 EcoBoost ST-Line X Petrol',
#  '2018 Honda HR-V 1.6 i-DTEC EX SUV 5dr Diesel (s/s) (120 ps) Hatchback Diesel Man',
#  'Lexus CT 200h 1.8 SE Plus Pack',
#  'Mercedes GLA 2.2 220d AMG Line Executive 4Matic DCT Diesel',
#  'Renault Laguna 2.0 16v Dynamique 5dr Petrol',
#  '2016 MERCEDES-BENZ GLA-CLASS 2.1 GLA 200 D AMG LINE 5d 134 BHP Diesel',
#  '2017 Volkswagen Polo 1.2 TSI Match Edition 5dr HATCHBACK Petrol Manual',
#  'Chevrolet Matiz 1.0 SE 5dr Petrol',
#  '2018 Ford Kuga 1.5 TDCi Titanium 5dr 2WD Manual Estate Diesel Manual',
#  'Renault Clio RENAULT CLIO 0.9 TCE 90 Iconic 5dr Petrol',
#  '2021 Ford S-MAX 2.0 EcoBlue 190 ST-Line 5dr Auto AWD MPV Diesel Automatic',
#  'KIA Sportage 1.7 CRDi 3 Diesel',
#  '2019 Ford Fiesta 1.0 EcoBoost Zetec 5dr Manual Hatchback Petrol Manual',
#  '2002 Volkswagen golf gti turbo',
#  '2018 Vauxhall Astra 1.4 SRI VX-LINE NAV Hatchback PETROL Manual',
#  'Bmw 320i automatic 2007 ulez compliant',
#  'Ford kuga 2015',
#  'Vauxhall insignia SRI TURBO 4x4 estate 224 bhp',
#  '53 REG LAND ROVER DISCOVERY 2.5 TD5 AUTOMATIC 7 SEATER',
#  '2015 Ford Fiesta 1.25 82 Zetec 3dr HATCHBACK Petrol Manual',
#  '2012 AUTOMATIC AUDI A4 2.0 BLACK EDITION AVANT',
#  'Dacia Sandero DACIA SANDERO 1.0 SCe Essential 5dr Petrol',
#  'BMW 5 Series 3.0 530d M Sport Auto (s/s) 4dr Diesel']

# %% [markdown]
# #### Car Details

# %% [markdown]
# #### Combine URLs

# %%
url_combined = []

for link in car_link:
    url_combined.append(urllib.parse.urljoin(root_url, link))

# %%
url_combined
# Out:
# ['https://www.gumtree.com/p/mercedes-benz/mercedes-benz-e-class-saloon-2018-semi-auto-1950-cc-4-doors/1431287322',
#  'https://www.gumtree.com/p/land-rover/2009-land-rover-discovery-4-3.0-td-v6-gs-auto-4wd-5dr-7-seats-low-miles-1-for/1426669013',
#  'https://www.gumtree.com/p/bmw/bmw-4-series-coupe-428i-241hp/1430163073',
#  'https://www.gumtree.com/p/volkswagen/hounslow-tw/1430411075',
#  'https://www.gumtree.com/p/mercedes-benz/mercedes-benz-a-class-2.1-a200d-amg-line-premium-plus-7g-dct-s-s-5dr/1421136528',
#  'https://www.gumtree.com/p/mercedes-benz/mercedes-benz-gla-estate-2016-semi-auto-1595-cc-5-doors/1431288397',
#  'https://www.gumtree.com/p/volkswagen/-2006-volkswagen-golf-gti-2.0-tfsi-dsg-hpi-clear-low-miles-full-fsh-/1431288213',
#  'https://www.gumtree.com/p/bmw/bmw-2-series-tourer-2.0-220i-luxury-active-tourer-petrol/1426180182',
#  'https://www.gumtree.com/p/ford/2020-ford-puma-1.0-ecoboost-hybrid-mhev-st-line-5dr-manual-hatchback-petrol-manu/1430907948',
#  'https://www.gumtree.com/p/volkswagen/volkswagen-golf-1.4-tsi-gt-dsg-5dr-petrol/1431063037',
#  'https://www.gumtree.com/p/vauxhall/2018-vauxhall-mokka-x-1.4-elite-nav-auto-hatchback-petrol-automatic/1430145739',
#  'https://www.gumtree.com/p/audi/2017-audi-a5-s5-quattro-2dr-tiptronic-convertible-petrol-automatic/1428339202',
#  'https://www.gumtree.com/p/toyota/toyota-c-hr-toyota-c-hr-1.8-hybrid-excel-5dr-cvt-leather-hybrid/1425755514',
#  'https://www.gumtree.com/p/ford/2021-ford-puma-1.0-ecoboost-hybrid-mhev-st-line-x-5dr-hatchback-petrol-manual/1427677057',
#  'https://www.gumtree.com/p/kia/2018-kia-stonic-1.0-t-gdi-2-manual-estate-petrol-manual/1427677295',
#  'https://www.gumtree.com/p/vauxhall/2019-vauxhall-mokka-x-1.4-active-auto-hatchback-petrol-automatic/1426259638',
#  'https://www.gumtree.com/p/peugeot/peugeot-3008-1.5-bluehdi-gt-line-diesel/1426180324',
#  'https://www.gumtree.com/p/mercedes-benz/mercedes-benz-gle-class-3.0l-gle-350-d-4matic-amg-line-premium-plus-4d-auto/1424655904',
#  'https://www.gumtree.com/p/hyundai/2020-hyundai-ioniq-38.3kwh-premium-hatchback-5dr-electric-auto-136-ps-hatchbac/1428569048',
#  'https://www.gumtree.com/p/mercedes-benz/mercedes-cla-2.2-200d-amg-line-diesel/1425745160',
#  'https://www.gumtree.com/p/toyota/toyota-aygo-1.0-vvt-i-x-cite-5dr-petrol/1425020989',
#  'https://www.gumtree.com/p/mini/2020-mini-hatchback-1.5-cooper-sport-ii-3dr-auto-hatchback-petrol-automatic/1426398750',
#  'https://www.gumtree.com/p/ford/ford-edge-2.0-tdci-210-sport-powershift-awd-diesel/1426180262',
#  'https://www.gumtree.com/p/nissan/nissan-qashqai-1.5-dci-acenta-premium-diesel/1425744889',
#  'https://www.gumtree.com/p/honda/2020-honda-honda-e-35.5kwh-advance-hatchback-5dr-electric-auto-17in-alloy-154/1426617023',
#  'https://www.gumtree.com/p/peugeot/2020-peugeot-308-1.5-bluehdi-s-s-allure-digital-auto-hatchback-diesel-automatic/1426621280',
#  'https://www.gumtree.com/p/ford/2019-ford-fiesta-1.0-ecoboost-zetec-navigation-5dr-manual-hatchback-petrol-manua/1430907038',
#  'https://www.gumtree.com/p/nissan/2021-nissan-leaf-110kw-10-40kwh-5dr-auto-automatic-hatchback-electric-automatic/1426823656',
#  'https://www.gumtree.com/p/ford/ford-focus-titanium-x/1430147901',
#  'https://www.gumtree.com/p/renault/renault-megane-1.5-dci-expression-diesel/1428999518',
#  'https://www.gumtree.com/p/volkswagen/2015-volkswagen-scirocco-2.0-tdi-184-bluemotion-tech-gt-3dr-coupe-diesel-manual/1430854391',
#  'https://www.gumtree.com/p/vauxhall/vauxhall-astra-1.6-16v-exclusiv-euro-5-5dr-petrol/1430945199',
#  'https://www.gumtree.com/p/renault/renault-megane-petrol-1.6cc-3dr-2010/1428226219',
#  'https://www.gumtree.com/p/mercedes-benz/mercedes-sl320-r129-for-sale/1428836184',
#  'https://www.gumtree.com/p/seat/seat-ibiza-toca-petrol-excellent-condition-drives-like-new-/1430731746',
#  'https://www.gumtree.com/p/hyundai/2017-hyundai-kona-1.6t-gdi-blue-drive-premium-gt-5dr-4wd-dct-semi-auto-hatchback/1426823749',
#  'https://www.gumtree.com/p/nissan/nissan-qashqai-1.5-dci-acenta-diesel/1425744681',
#  'https://www.gumtree.com/p/mercedes-benz/mercedes-benz-c180-auto-petrol-ulez-free-full-service-history-c-class-saloon-e-cheap-car/1431287787',
#  'https://www.gumtree.com/p/land-rover/range-rover-vogue-v8/1431287713',
#  'https://www.gumtree.com/p/mercedes-benz/mercedes-benz-e-class-saloon-2018-semi-auto-1950-cc-4-doors/1431287322',
#  'https://www.gumtree.com/p/mini/mini-one-2007-ulez-free-100k/1431287309',
#  'https://www.gumtree.com/p/bmw/bmw-325i-se-/1431287131',
#  'https://www.gumtree.com/p/volkswagen/2015-volkswagen-polo-1.2-tsi-bluemotion-tech-se-dsg-s-s-5dr-20£tax-auto-ule/1423709871',
#  'https://www.gumtree.com/p/toyota/toyota-corolla-1.8-vvtl-i-t-sport-3dr-petrol/1431061973',
#  'https://www.gumtree.com/p/mercedes-benz/mercedes-benz-sl-class-5.0-sl500-silver-arrow-limited-edition-2dr-petrol/1422729866',
#  'https://www.gumtree.com/p/honda/honda-civic-1.6-i-dtec-black-edition-5dr-diesel/1425603212',
#  'https://www.gumtree.com/p/honda/2019-honda-jazz-1.3-i-vtec-se-hatchback-5dr-petrol-s-s-102-ps-hatchback-petr/1425522805',
#  'https://www.gumtree.com/p/mini/mini-hatch-1.5-cooper-chili-pack-petrol/1426616523',
#  'https://www.gumtree.com/p/ford/2019-ford-ecosport-5dr-st-line-1.0-125ps-hatchback-petrol-manual/1428338039',
#  'https://www.gumtree.com/p/volkswagen/volkswagen-golf-1.4-tsi-bluemotion-tech-match-dsg-5dr-stop-start/1429001906',
#  'https://www.gumtree.com/p/nissan/nissan-qashqai-1.5-dci-tekna-5dr-diesel/1423478327',
#  'https://www.gumtree.com/p/bmw/2016-bmw-1-series-118i-1.5-se-5dr-nav-hatchback-petrol-manual/1423951617',
#  'https://www.gumtree.com/p/land-rover/2019-land-rover-range-rover-sport-2.0-p400e-hse-dynamic-5dr-auto-suv-petrol-plu-/1431061979',
#  'https://www.gumtree.com/p/nissan/nissan-qashqai-1.6-dci-tekna-5dr-diesel/1429443683',
#  'https://www.gumtree.com/p/ford/2020-ford-puma-1.0-ecoboost-hybrid-mhev-155-st-line-x-1st-ed-5dr-hatchback-petro/1427904627',
#  'https://www.gumtree.com/p/volkswagen/volkswagen-tiguan-2.0-tdi-150-s-4motion-dsg-diesel/1426615894',
#  'https://www.gumtree.com/p/renault/renault-captur-renault-captur-0.9-tce-90-iconic-5dr-petrol/1428269244',
#  'https://www.gumtree.com/p/nissan/2018-nissan-juke-1.6-tekna-5dr-xtronic-auto-hatchback-petrol-automatic/1428789673',
#  'https://www.gumtree.com/p/nissan/2019-nissan-qashqai-1.3-dig-t-160-n-connecta-5dr-dct-semi-auto-hatchback-petrol-/1430373648',
#  'https://www.gumtree.com/p/toyota/toyota-voxy-1.8-hybrid-7-seats-mpv-mpv-petrol-electric-hybrid-automatic/1429685098',
#  'https://www.gumtree.com/p/bmw/bmw-5-series-ulez-big-spec/1430369955',
#  'https://www.gumtree.com/p/mercedes-benz/mercedes-benz-e-class-2.1-e250-cdi-blueefficiency-se-2dr-diesel/1417278666',
#  'https://www.gumtree.com/p/ford/lhd-2016-ford-kuga-2.0-tdci-automatic-titanium-individual/1416505370',
#  'https://www.gumtree.com/p/ford/2012-ford-focus-1.6-zetec-5dr-full-service-history-7-stamps-only-32000-miles-/1419696247',
#  'https://www.gumtree.com/p/audi/audi-a6-saloon-3.0-tdi-le-mans-quattro-4dr-diesel/1430945677',
#  'https://www.gumtree.com/p/vauxhall/vauxhall-mokka-x-1.4-t-elite-petrol/1425962630',
#  'https://www.gumtree.com/p/seat/seat-arona-1.6-tdi-xcellence-lux-ez-dsg-diesel/1426616224',
#  'https://www.gumtree.com/p/ford/ford-kuga-1.5-ecoboost-st-line-x-petrol/1425744103',
#  'https://www.gumtree.com/p/honda/2018-honda-hr-v-1.6-i-dtec-ex-suv-5dr-diesel-s-s-120-ps-hatchback-diesel-man/1425298710',
#  'https://www.gumtree.com/p/lexus/lexus-ct-200h-1.8-se-plus-pack/1430144782',
#  'https://www.gumtree.com/p/mercedes-benz/mercedes-gla-2.2-220d-amg-line-executive-4matic-dct-diesel/1425743417',
#  'https://www.gumtree.com/p/renault/renault-laguna-2.0-16v-dynamique-5dr-petrol/1428268959',
#  'https://www.gumtree.com/p/mercedes-benz/2016-mercedes-benz-gla-class-2.1-gla-200-d-amg-line-5d-134-bhp-diesel/1426616122',
#  'https://www.gumtree.com/p/volkswagen/2017-volkswagen-polo-1.2-tsi-match-edition-5dr-hatchback-petrol-manual/1429685283',
#  'https://www.gumtree.com/p/chevrolet/chevrolet-matiz-1.0-se-5dr-petrol/1428789496',
#  'https://www.gumtree.com/p/ford/2018-ford-kuga-1.5-tdci-titanium-5dr-2wd-manual-estate-diesel-manual/1430906836',
#  'https://www.gumtree.com/p/renault/renault-clio-renault-clio-0.9-tce-90-iconic-5dr-petrol/1428269655',
#  'https://www.gumtree.com/p/ford/2021-ford-s-max-2.0-ecoblue-190-st-line-5dr-auto-awd-mpv-diesel-automatic/1427676651',
#  'https://www.gumtree.com/p/kia/kia-sportage-1.7-crdi-3-diesel/1426616429',
#  'https://www.gumtree.com/p/ford/2019-ford-fiesta-1.0-ecoboost-zetec-5dr-manual-hatchback-petrol-manual/1430906945',
#  'https://www.gumtree.com/p/volkswagen/2002-volkswagen-golf-gti-turbo/1431287103',
#  'https://www.gumtree.com/p/vauxhall/2018-vauxhall-astra-1.4-sri-vx-line-nav-hatchback-petrol-manual/1431287049',
#  'https://www.gumtree.com/p/bmw/bmw-320i-automatic-2007-ulez-compliant-/1431286944',
#  'https://www.gumtree.com/p/ford/ford-kuga-2015/1431286635',
#  'https://www.gumtree.com/p/vauxhall/vauxhall-insignia-sri-turbo-4x4-estate-224-bhp/1431286634',
#  'https://www.gumtree.com/p/land-rover/53-reg-land-rover-discovery-2.5-td5-automatic-7-seater/1431286609',
#  'https://www.gumtree.com/p/ford/2015-ford-fiesta-1.25-82-zetec-3dr-hatchback-petrol-manual/1431286608',
#  'https://www.gumtree.com/p/audi/2012-automatic-audi-a4-2.0-black-edition-avant/1431286493',
#  'https://www.gumtree.com/p/dacia/dacia-sandero-dacia-sandero-1.0-sce-essential-5dr-petrol/1428268854',
#  'https://www.gumtree.com/p/bmw/bmw-5-series-3.0-530d-m-sport-auto-s-s-4dr-diesel/1423477273']

# %% [markdown]
# ### Create Pandas Dataframe

# %%
car_overview = pd.DataFrame({'Name' : car_name, 
                             'Price' : car_price,
                             'Details' : car_details,
                             'Location' : car_location,
                             'Link' : url_combined})

# %%
car_overview = car_overview[car_overview["Price"].str.contains("n/a") == False]

# %%
car_overview['Details'].str.split(',')
# Out:
# 0     [Year 2018,  Mileage 36, 000 miles,  Fuel type...
# 1     [Year 2009,  Mileage 63, 200 miles,  Seller ty...
# 2     [Year 2013,  Mileage 112, 000 miles,  Fuel typ...
# 3     [Year 2007,  Mileage 116 miles,  Fuel type Die...
# 4     [Year 2018,  Mileage 40, 088 miles,  Seller ty...
#                             ...
# 85    [Year 2003,  Mileage 128, 000 miles,  Seller t...
# 86    [Year 2015,  Mileage 51, 350 miles,  Seller ty...
# 87    [Year 2012,  Mileage 92, 000 miles,  Fuel type...
# 88    [Year 2019,  Mileage 50, 940 miles,  Seller ty...
# 89    [Year 2018,  Mileage 37, 000 miles,  Seller ty...
# Name: Details, Length: 90, dtype: object

# %%
car_overview['Details'].str.split(r",\s*(?![^()]*\))", n=1)
# Out:
# 0     [Year 2018, Mileage 36,000 miles, Fuel type Di...
# 1     [Year 2009, Mileage 63,200 miles, Seller type ...
# 2     [Year 2013, Mileage 112,000 miles, Fuel type P...
# 3     [Year 2007, Mileage 116 miles, Fuel type Diese...
# 4     [Year 2018, Mileage 40,088 miles, Seller type ...
#                             ...
# 85    [Year 2003, Mileage 128,000 miles, Seller type...
# 86    [Year 2015, Mileage 51,350 miles, Seller type ...
# 87    [Year 2012, Mileage 92,000 miles, Fuel type Pe...
# 88    [Year 2019, Mileage 50,940 miles, Seller type ...
# 89    [Year 2018, Mileage 37,000 miles, Seller type ...
# Name: Details, Length: 90, dtype: object

# %%
split_details = car_overview['Details'].str.split(r", \s*(?![^()]*\))", n=2, expand = True)
split_details.rename(columns={0:"Year", 1:"Mileage", 2:"Additional Details"})
car_overview[['Year', 'Mileage','Additional Details']] = car_overview['Details'].str.split(', ',n=2, expand=True)

# %%
car_overview
# Out:
#                                                  Name    Price  \
# 0   Mercedes-Benz, E CLASS, Saloon, 2018, Semi-Aut...  £22,495
# 1   2009 Land Rover Discovery 4 3.0 TD V6 GS Auto ...  £13,980
# 2                       BMW 4 SERIES COUPE 428i 241HP  £11,500
# 3                                         Hounslow Tw   £1,350
# 4   Mercedes-Benz A Class 2.1 A200d AMG Line (Prem...  £19,495
# ..                                                ...      ...
# 85  53 REG LAND ROVER DISCOVERY 2.5 TD5 AUTOMATIC ...   £4,995
# 86  2015 Ford Fiesta 1.25 82 Zetec 3dr HATCHBACK P...   £7,145
# 87     2012 AUTOMATIC AUDI A4 2.0 BLACK EDITION AVANT  £10,950
# 88  Dacia Sandero DACIA SANDERO 1.0 SCe Essential ...   £7,400
# 89  BMW 5 Series 3.0 530d M Sport Auto (s/s) 4dr D...  £27,489
#
#                                               Details               Location  \
# 0   Year 2018, Mileage 36,000 miles, Fuel type Die...       East Ham, London
# 1   Year 2009, Mileage 63,200 miles, Seller type T...       Edmonton, London
# 2   Year 2013, Mileage 112,000 miles, Fuel type Pe...   Surrey Quays, London
# 3   Year 2007, Mileage 116 miles, Fuel type Diesel...       Heathrow, London
# 4   Year 2018, Mileage 40,088 miles, Seller type T...        Mitcham, London
# ..                                                ...                    ...
# 85  Year 2003, Mileage 128,000 miles, Seller type ...        Romford, London
# 86  Year 2015, Mileage 51,350 miles, Seller type T...  Palmers Green, London
# 87  Year 2012, Mileage 92,000 miles, Fuel type Pet...      Islington, London
# 88  Year 2019, Mileage 50,940 miles, Seller type T...        Enfield, London
# 89  Year 2018, Mileage 37,000 miles, Seller type T...        Norbury, London
#
#                                                  Link       Year  \
# 0   https://www.gumtree.com/p/mercedes-benz/merced...  Year 2018
# 1   https://www.gumtree.com/p/land-rover/2009-land...  Year 2009
# 2   https://www.gumtree.com/p/bmw/bmw-4-series-cou...  Year 2013
# 3   https://www.gumtree.com/p/volkswagen/hounslow-...  Year 2007
# 4   https://www.gumtree.com/p/mercedes-benz/merced...  Year 2018
# ..                                                ...        ...
# 85  https://www.gumtree.com/p/land-rover/53-reg-la...  Year 2003
# 86  https://www.gumtree.com/p/ford/2015-ford-fiest...  Year 2015
# 87  https://www.gumtree.com/p/audi/2012-automatic-...  Year 2012
# 88  https://www.gumtree.com/p/dacia/dacia-sandero-...  Year 2019
# 89  https://www.gumtree.com/p/bmw/bmw-5-series-3.0...  Year 2018
#
#                   Mileage                                 Additional Details
# 0    Mileage 36,000 miles             Fuel type Diesel, Engine size 1,950 cc
# 1    Mileage 63,200 miles  Seller type Trade, Fuel type Diesel, Engine si...
# 2   Mileage 112,000 miles             Fuel type Petrol, Engine size 1,997 cc
# 3       Mileage 116 miles             Fuel type Diesel, Engine size 1,968 cc
# 4    Mileage 40,088 miles  Seller type Trade, Fuel type Diesel, Engine si...
# ..                    ...                                                ...
# 85  Mileage 128,000 miles  Seller type Trade, Fuel type Diesel, Engine si...
# 86   Mileage 51,350 miles  Seller type Trade, Fuel type Petrol, Engine si...
# 87   Mileage 92,000 miles             Fuel type Petrol, Engine size 1,984 cc
# 88   Mileage 50,940 miles  Seller type Trade, Fuel type Petrol, Engine si...
# 89   Mileage 37,000 miles  Seller type Trade, Fuel type Diesel, Engine si...
#
# [90 rows x 8 columns]

# %%
year_column = car_overview.pop('Year')

# %%
car_overview.insert(2, 'Year', year_column)
car_overview
# Out:
#                                                  Name    Price       Year  \
# 0   Mercedes-Benz, E CLASS, Saloon, 2018, Semi-Aut...  £22,495  Year 2018
# 1   2009 Land Rover Discovery 4 3.0 TD V6 GS Auto ...  £13,980  Year 2009
# 2                       BMW 4 SERIES COUPE 428i 241HP  £11,500  Year 2013
# 3                                         Hounslow Tw   £1,350  Year 2007
# 4   Mercedes-Benz A Class 2.1 A200d AMG Line (Prem...  £19,495  Year 2018
# ..                                                ...      ...        ...
# 85  53 REG LAND ROVER DISCOVERY 2.5 TD5 AUTOMATIC ...   £4,995  Year 2003
# 86  2015 Ford Fiesta 1.25 82 Zetec 3dr HATCHBACK P...   £7,145  Year 2015
# 87     2012 AUTOMATIC AUDI A4 2.0 BLACK EDITION AVANT  £10,950  Year 2012
# 88  Dacia Sandero DACIA SANDERO 1.0 SCe Essential ...   £7,400  Year 2019
# 89  BMW 5 Series 3.0 530d M Sport Auto (s/s) 4dr D...  £27,489  Year 2018
#
#                                               Details               Location  \
# 0   Year 2018, Mileage 36,000 miles, Fuel type Die...       East Ham, London
# 1   Year 2009, Mileage 63,200 miles, Seller type T...       Edmonton, London
# 2   Year 2013, Mileage 112,000 miles, Fuel type Pe...   Surrey Quays, London
# 3   Year 2007, Mileage 116 miles, Fuel type Diesel...       Heathrow, London
# 4   Year 2018, Mileage 40,088 miles, Seller type T...        Mitcham, London
# ..                                                ...                    ...
# 85  Year 2003, Mileage 128,000 miles, Seller type ...        Romford, London
# 86  Year 2015, Mileage 51,350 miles, Seller type T...  Palmers Green, London
# 87  Year 2012, Mileage 92,000 miles, Fuel type Pet...      Islington, London
# 88  Year 2019, Mileage 50,940 miles, Seller type T...        Enfield, London
# 89  Year 2018, Mileage 37,000 miles, Seller type T...        Norbury, London
#
#                                                  Link                Mileage  \
# 0   https://www.gumtree.com/p/mercedes-benz/merced...   Mileage 36,000 miles
# 1   https://www.gumtree.com/p/land-rover/2009-land...   Mileage 63,200 miles
# 2   https://www.gumtree.com/p/bmw/bmw-4-series-cou...  Mileage 112,000 miles
# 3   https://www.gumtree.com/p/volkswagen/hounslow-...      Mileage 116 miles
# 4   https://www.gumtree.com/p/mercedes-benz/merced...   Mileage 40,088 miles
# ..                                                ...                    ...
# 85  https://www.gumtree.com/p/land-rover/53-reg-la...  Mileage 128,000 miles
# 86  https://www.gumtree.com/p/ford/2015-ford-fiest...   Mileage 51,350 miles
# 87  https://www.gumtree.com/p/audi/2012-automatic-...   Mileage 92,000 miles
# 88  https://www.gumtree.com/p/dacia/dacia-sandero-...   Mileage 50,940 miles
# 89  https://www.gumtree.com/p/bmw/bmw-5-series-3.0...   Mileage 37,000 miles
#
#                                    Additional Details
# 0              Fuel type Diesel, Engine size 1,950 cc
# 1   Seller type Trade, Fuel type Diesel, Engine si...
# 2              Fuel type Petrol, Engine size 1,997 cc
# 3              Fuel type Diesel, Engine size 1,968 cc
# 4   Seller type Trade, Fuel type Diesel, Engine si...
# ..                                                ...
# 85  Seller type Trade, Fuel type Diesel, Engine si...
# 86  Seller type Trade, Fuel type Petrol, Engine si...
# 87             Fuel type Petrol, Engine size 1,984 cc
# 88  Seller type Trade, Fuel type Petrol, Engine si...
# 89  Seller type Trade, Fuel type Diesel, Engine si...
#
# [90 rows x 8 columns]

# %%
mileage_column = car_overview.pop('Mileage')

# %%
car_overview.insert(3, 'Mileage', mileage_column)
car_overview
# Out:
#                                                  Name    Price       Year  \
# 0   Mercedes-Benz, E CLASS, Saloon, 2018, Semi-Aut...  £22,495  Year 2018
# 1   2009 Land Rover Discovery 4 3.0 TD V6 GS Auto ...  £13,980  Year 2009
# 2                       BMW 4 SERIES COUPE 428i 241HP  £11,500  Year 2013
# 3                                         Hounslow Tw   £1,350  Year 2007
# 4   Mercedes-Benz A Class 2.1 A200d AMG Line (Prem...  £19,495  Year 2018
# ..                                                ...      ...        ...
# 85  53 REG LAND ROVER DISCOVERY 2.5 TD5 AUTOMATIC ...   £4,995  Year 2003
# 86  2015 Ford Fiesta 1.25 82 Zetec 3dr HATCHBACK P...   £7,145  Year 2015
# 87     2012 AUTOMATIC AUDI A4 2.0 BLACK EDITION AVANT  £10,950  Year 2012
# 88  Dacia Sandero DACIA SANDERO 1.0 SCe Essential ...   £7,400  Year 2019
# 89  BMW 5 Series 3.0 530d M Sport Auto (s/s) 4dr D...  £27,489  Year 2018
#
#                   Mileage                                            Details  \
# 0    Mileage 36,000 miles  Year 2018, Mileage 36,000 miles, Fuel type Die...
# 1    Mileage 63,200 miles  Year 2009, Mileage 63,200 miles, Seller type T...
# 2   Mileage 112,000 miles  Year 2013, Mileage 112,000 miles, Fuel type Pe...
# 3       Mileage 116 miles  Year 2007, Mileage 116 miles, Fuel type Diesel...
# 4    Mileage 40,088 miles  Year 2018, Mileage 40,088 miles, Seller type T...
# ..                    ...                                                ...
# 85  Mileage 128,000 miles  Year 2003, Mileage 128,000 miles, Seller type ...
# 86   Mileage 51,350 miles  Year 2015, Mileage 51,350 miles, Seller type T...
# 87   Mileage 92,000 miles  Year 2012, Mileage 92,000 miles, Fuel type Pet...
# 88   Mileage 50,940 miles  Year 2019, Mileage 50,940 miles, Seller type T...
# 89   Mileage 37,000 miles  Year 2018, Mileage 37,000 miles, Seller type T...
#
#                  Location                                               Link  \
# 0        East Ham, London  https://www.gumtree.com/p/mercedes-benz/merced...
# 1        Edmonton, London  https://www.gumtree.com/p/land-rover/2009-land...
# 2    Surrey Quays, London  https://www.gumtree.com/p/bmw/bmw-4-series-cou...
# 3        Heathrow, London  https://www.gumtree.com/p/volkswagen/hounslow-...
# 4         Mitcham, London  https://www.gumtree.com/p/mercedes-benz/merced...
# ..                    ...                                                ...
# 85        Romford, London  https://www.gumtree.com/p/land-rover/53-reg-la...
# 86  Palmers Green, London  https://www.gumtree.com/p/ford/2015-ford-fiest...
# 87      Islington, London  https://www.gumtree.com/p/audi/2012-automatic-...
# 88        Enfield, London  https://www.gumtree.com/p/dacia/dacia-sandero-...
# 89        Norbury, London  https://www.gumtree.com/p/bmw/bmw-5-series-3.0...
#
#                                    Additional Details
# 0              Fuel type Diesel, Engine size 1,950 cc
# 1   Seller type Trade, Fuel type Diesel, Engine si...
# 2              Fuel type Petrol, Engine size 1,997 cc
# 3              Fuel type Diesel, Engine size 1,968 cc
# 4   Seller type Trade, Fuel type Diesel, Engine si...
# ..                                                ...
# 85  Seller type Trade, Fuel type Diesel, Engine si...
# 86  Seller type Trade, Fuel type Petrol, Engine si...
# 87             Fuel type Petrol, Engine size 1,984 cc
# 88  Seller type Trade, Fuel type Petrol, Engine si...
# 89  Seller type Trade, Fuel type Diesel, Engine si...
#
# [90 rows x 8 columns]

# %%
additional_details_column = car_overview.pop('Additional Details')

# %%
car_overview.insert(4, 'Additional Details', additional_details_column)
car_overview
# Out:
#                                                  Name    Price       Year  \
# 0   Mercedes-Benz, E CLASS, Saloon, 2018, Semi-Aut...  £22,495  Year 2018
# 1   2009 Land Rover Discovery 4 3.0 TD V6 GS Auto ...  £13,980  Year 2009
# 2                       BMW 4 SERIES COUPE 428i 241HP  £11,500  Year 2013
# 3                                         Hounslow Tw   £1,350  Year 2007
# 4   Mercedes-Benz A Class 2.1 A200d AMG Line (Prem...  £19,495  Year 2018
# ..                                                ...      ...        ...
# 85  53 REG LAND ROVER DISCOVERY 2.5 TD5 AUTOMATIC ...   £4,995  Year 2003
# 86  2015 Ford Fiesta 1.25 82 Zetec 3dr HATCHBACK P...   £7,145  Year 2015
# 87     2012 AUTOMATIC AUDI A4 2.0 BLACK EDITION AVANT  £10,950  Year 2012
# 88  Dacia Sandero DACIA SANDERO 1.0 SCe Essential ...   £7,400  Year 2019
# 89  BMW 5 Series 3.0 530d M Sport Auto (s/s) 4dr D...  £27,489  Year 2018
#
#                   Mileage                                 Additional Details  \
# 0    Mileage 36,000 miles             Fuel type Diesel, Engine size 1,950 cc
# 1    Mileage 63,200 miles  Seller type Trade, Fuel type Diesel, Engine si...
# 2   Mileage 112,000 miles             Fuel type Petrol, Engine size 1,997 cc
# 3       Mileage 116 miles             Fuel type Diesel, Engine size 1,968 cc
# 4    Mileage 40,088 miles  Seller type Trade, Fuel type Diesel, Engine si...
# ..                    ...                                                ...
# 85  Mileage 128,000 miles  Seller type Trade, Fuel type Diesel, Engine si...
# 86   Mileage 51,350 miles  Seller type Trade, Fuel type Petrol, Engine si...
# 87   Mileage 92,000 miles             Fuel type Petrol, Engine size 1,984 cc
# 88   Mileage 50,940 miles  Seller type Trade, Fuel type Petrol, Engine si...
# 89   Mileage 37,000 miles  Seller type Trade, Fuel type Diesel, Engine si...
#
#                                               Details               Location  \
# 0   Year 2018, Mileage 36,000 miles, Fuel type Die...       East Ham, London
# 1   Year 2009, Mileage 63,200 miles, Seller type T...       Edmonton, London
# 2   Year 2013, Mileage 112,000 miles, Fuel type Pe...   Surrey Quays, London
# 3   Year 2007, Mileage 116 miles, Fuel type Diesel...       Heathrow, London
# 4   Year 2018, Mileage 40,088 miles, Seller type T...        Mitcham, London
# ..                                                ...                    ...
# 85  Year 2003, Mileage 128,000 miles, Seller type ...        Romford, London
# 86  Year 2015, Mileage 51,350 miles, Seller type T...  Palmers Green, London
# 87  Year 2012, Mileage 92,000 miles, Fuel type Pet...      Islington, London
# 88  Year 2019, Mileage 50,940 miles, Seller type T...        Enfield, London
# 89  Year 2018, Mileage 37,000 miles, Seller type T...        Norbury, London
#
#                                                  Link
# 0   https://www.gumtree.com/p/mercedes-benz/merced...
# 1   https://www.gumtree.com/p/land-rover/2009-land...
# 2   https://www.gumtree.com/p/bmw/bmw-4-series-cou...
# 3   https://www.gumtree.com/p/volkswagen/hounslow-...
# 4   https://www.gumtree.com/p/mercedes-benz/merced...
# ..                                                ...
# 85  https://www.gumtree.com/p/land-rover/53-reg-la...
# 86  https://www.gumtree.com/p/ford/2015-ford-fiest...
# 87  https://www.gumtree.com/p/audi/2012-automatic-...
# 88  https://www.gumtree.com/p/dacia/dacia-sandero-...
# 89  https://www.gumtree.com/p/bmw/bmw-5-series-3.0...
#
# [90 rows x 8 columns]

# %%
del car_overview['Details']

# %%
car_overview['Year'] = car_overview['Year'].str.replace('Year', '')
car_overview['Mileage'] = car_overview['Mileage'].str.replace('Mileage', '')
car_overview['Additional Details'] = car_overview['Additional Details'].str.replace('Seller type', 'Seller type:')
car_overview['Additional Details'] = car_overview['Additional Details'].str.replace('Fuel type', 'Fuel type:')
car_overview['Additional Details'] = car_overview['Additional Details'].str.replace('Engine size', 'Engine size:')

# %%
car_overview
# Out:
#                                                  Name    Price   Year  \
# 0   Mercedes-Benz, E CLASS, Saloon, 2018, Semi-Aut...  £22,495   2018
# 1   2009 Land Rover Discovery 4 3.0 TD V6 GS Auto ...  £13,980   2009
# 2                       BMW 4 SERIES COUPE 428i 241HP  £11,500   2013
# 3                                         Hounslow Tw   £1,350   2007
# 4   Mercedes-Benz A Class 2.1 A200d AMG Line (Prem...  £19,495   2018
# ..                                                ...      ...    ...
# 85  53 REG LAND ROVER DISCOVERY 2.5 TD5 AUTOMATIC ...   £4,995   2003
# 86  2015 Ford Fiesta 1.25 82 Zetec 3dr HATCHBACK P...   £7,145   2015
# 87     2012 AUTOMATIC AUDI A4 2.0 BLACK EDITION AVANT  £10,950   2012
# 88  Dacia Sandero DACIA SANDERO 1.0 SCe Essential ...   £7,400   2019
# 89  BMW 5 Series 3.0 530d M Sport Auto (s/s) 4dr D...  £27,489   2018
#
#            Mileage                                 Additional Details  \
# 0     36,000 miles           Fuel type: Diesel, Engine size: 1,950 cc
# 1     63,200 miles  Seller type: Trade, Fuel type: Diesel, Engine ...
# 2    112,000 miles           Fuel type: Petrol, Engine size: 1,997 cc
# 3        116 miles           Fuel type: Diesel, Engine size: 1,968 cc
# 4     40,088 miles  Seller type: Trade, Fuel type: Diesel, Engine ...
# ..             ...                                                ...
# 85   128,000 miles  Seller type: Trade, Fuel type: Diesel, Engine ...
# 86    51,350 miles  Seller type: Trade, Fuel type: Petrol, Engine ...
# 87    92,000 miles           Fuel type: Petrol, Engine size: 1,984 cc
# 88    50,940 miles  Seller type: Trade, Fuel type: Petrol, Engine ...
# 89    37,000 miles  Seller type: Trade, Fuel type: Diesel, Engine ...
#
#                  Location                                               Link
# 0        East Ham, London  https://www.gumtree.com/p/mercedes-benz/merced...
# 1        Edmonton, London  https://www.gumtree.com/p/land-rover/2009-land...
# 2    Surrey Quays, London  https://www.gumtree.com/p/bmw/bmw-4-series-cou...
# 3        Heathrow, London  https://www.gumtree.com/p/volkswagen/hounslow-...
# 4         Mitcham, London  https://www.gumtree.com/p/mercedes-benz/merced...
# ..                    ...                                                ...
# 85        Romford, London  https://www.gumtree.com/p/land-rover/53-reg-la...
# 86  Palmers Green, London  https://www.gumtree.com/p/ford/2015-ford-fiest...
# 87      Islington, London  https://www.gumtree.com/p/audi/2012-automatic-...
# 88        Enfield, London  https://www.gumtree.com/p/dacia/dacia-sandero-...
# 89        Norbury, London  https://www.gumtree.com/p/bmw/bmw-5-series-3.0...
#
# [90 rows x 7 columns]

# %% [markdown]
# ### Output in Excel

# %%
car_overview.to_excel('car_results2.xls', index = False)
# Out:
# C:\Users\sanck\AppData\Local\Temp/ipykernel_15032/1381407577.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   car_overview.to_excel('car_results2.xls', index = False)
